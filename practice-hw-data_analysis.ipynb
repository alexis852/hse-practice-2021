# %% [markdown]
# # Домашнее задание по мини-курсу "Анализ и обработка веб-данных на Python"
#
# В качестве ДЗ я решил написать web-scraper, который соберет информацию обо всех образовательных программах бакалавриата московского кампуса ВШЭ и будет парсить страницы с рейтингами студентов этих программ, представляя их в удобном для обработки и анализа виде.
#
# С помощью этого скрапера и пакета ```matplotlib``` я соберу, проанализирую и визуализирую данные о среднем показателе GPA (Grade Point Average), а также о среднем количестве отчисленных студентов по всем факультетам московской Вышки за 2018/2019, 2019/2020 и 2020/2021 учебные годы.

# %% [markdown]
# ## 1. Первичный сбор данных
#
# Сперва посмотрим на сайт образовательных программ Вышки и поймем, как можно достать оттуда нужные нам данные.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.hse.ru/education/msk/bachelor/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Программы бакалавриата НИУ ВШЭ в Москве – Образовательные программы НИУ ВШЭ – Национальный исследовательский университет «Высшая школа экономики»
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.hse.ru/education/bachelor/" rel="canonical"/>
#   <link href="/f/src/global/i/favicon/favicon_ios_180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/f/src/global/i/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/f/src/global/i/favicon/favicon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#242f63" href="/f/src/global/i/favicon/favicon.svg" rel="mask-icon"/>
#   <link href="/f/src/manifest/manifest_ru.json" rel="manifest"/>
#   <meta content="/f/src/global/i/favicon/browserconfig.xml" name="msapplication-config"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Программы бакалавриата НИУ ВШЭ в Москве" property="og:title"/>
#   <meta content="Программы бакалавриата НИУ ВШЭ в Москве" name="mrc__share_title"/>
#   <meta content="Программы бакалавриата НИУ ВШЭ в Москве" itemprop="name"/>
#   <meta content="Высшая школа экономики — это отличный старт для карьеры в бизнесе, на государственной службе и в науке. Здесь готовят высококлассных специалистов, нужных стране.
# " property="og:description"/>
#   <meta content="Высшая школа экономики — это отличный старт для карьеры в бизнесе, на государственной службе и в науке. Здесь готовят высококлассных специалистов, нужных стране.
# " name="mrc__share_description"/>
#   <meta content="Высшая школа экономики — это отличный старт для карьеры в бизнесе, на государственной службе и в науке. Здесь готовят высококлассных специалистов, нужных стране.
# " itemprop="description"/>
#   <meta content="Высшая школа экономики — это отличный старт для карьеры в бизнесе, на государственной службе и в науке. Здесь готовят высококлассных специалистов, нужных стране.
# " name="twitter:description"/>
#   <meta content="https://www.hse.ru/images/fb/hse_ru_thumb.jpg" property="og:image"/>
#   <meta content="https://www.hse.ru/images/fb/hse_ru_thumb.jpg" itemprop="image"/>
#   <link href="https://www.hse.ru/images/fb/hse_ru_thumb.jpg" rel="image_src"/>
#   <meta content="https://www.hse.ru/images/fb/hse_ru_thumb.jpg" name="twitter:image"/>
#   <meta content="https://www.hse.ru/education/bachelor/" property="og:url"/>
#   <meta content="https://www.hse.ru/education/bachelor/" name="twitter:url"/>
#   <meta content="website" property="og:type"/>
#   <link href="/f/src/projects/unshm1/unshm1.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/sitemap.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/vision.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/edu/css/edu2.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/owl.carousel2.min.css" media="all" rel="stylesheet"/>
#   <!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->
#   <script src="/f/src/global/js/cache/jquery-1.10.1.min/jquery.cookie/jquery-ui/jquery.ui.touch-punch.min/hse.utils/errtrack/main/modernizr/popup/switcher/tag/jquery.cookie/sitemap.ajax/vision/ctrlshifte/fotorama/owl.carousel2.min/emerge/events-switcher/masonry.pkgd.min/imagesloaded.pkgd.min/universal.js">
#   </script>
#   <script src="/f/src/global/node_modules/classlist-polyfill/src/index.js" type="text/javascript">
#   </script>
#   <script src="/f/src/global/js/gibs.js" type="text/javascript">
#   </script>
#   <!-- counter-->
#   <script src="/f/gtm/ip">
#   </script>
#   <script type="text/javascript">
#    <!--
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-P6DCQX');
# //-->
#   </script>
#   <!-- /counter-->
#   <script async="" src="https://www.hse.ru/f/src/global/js/job.js">
#   </script>
#   <script>
#    var education_initial_campus = 51999662;
# var sidebar_filters_scheme = {"type":"bachelor","items":[{"value":51999662,"name":"campus","title":"Кампус","type":"switcher","items":[{"value":"0","title":"Все кампусы"},{"value":51999662,"title":"Москва"},{"value":51999665,"title":"Санкт-Петербург"},{"value":51999664,"title":"Нижний Новгород"},{"value":51999666,"title":"Пермь"}]},{"folded":"true","value":null,"name":"direction_magister","withNull":1,"hidden":1,"type":"select","class":"select_magister","title":"Направление подготовки","items":[{"value":[52587439],"title":"Бизнес-информатика"},{"value":[463549512],"title":"Биотехнология"},{"value":[216492023],"title":"Востоковедение и африканистика"},{"value":[53352648],"title":"Государственное и муниципальное управление"},{"value":[53352649],"title":"Градостроительство"},{"value":[74573516],"title":"Дизайн"},{"value":[53352650],"title":"Журналистика"},{"value":[312178671],"title":"Зарубежное регионоведение"},{"value":[250131938],"title":"Изящные искусства"},{"value":[53352651],"title":"Инноватика"},{"value":[209009303],"title":"Инфокоммуникационные технологии и системы связи"},{"value":[74573517],"title":"Информатика и вычислительная техника"},{"value":[416622129],"title":"Информационная безопасность"},{"value":[53352652],"title":"История"},{"value":[212814652],"title":"История искусств"},{"value":[53352653],"title":"Культурология"},{"value":[138534234],"title":"Лингвистика"},{"value":[53352655],"title":"Математика"},{"value":[141119960],"title":"Медиакоммуникации"},{"value":[53189947],"title":"Международные отношения"},{"value":[53352656],"title":"Менеджмент"},{"value":[212250432],"title":"Педагогическое образование"},{"value":[53352657],"title":"Политология"},{"value":[74573518],"title":"Прикладная математика"},{"value":[53352699],"title":"Прикладная математика и информатика"},{"value":[53352700],"title":"Программная инженерия"},{"value":[53352701],"title":"Психология"},{"value":[74573519],"title":"Реклама и связи с общественностью"},{"value":[53352702],"title":"Социология"},{"value":[212325758],"title":"Спорт"},{"value":[195513148],"title":"Физика"},{"value":[53352698],"title":"Филология"},{"value":[53352703],"title":"Философия"},{"value":[51999691],"title":"Финансы и кредит"},{"value":[53352697],"title":"Фундаментальная и прикладная лингвистика"},{"value":[53352704],"title":"Экономика"},{"value":[74573520],"title":"Электроника и наноэлектроника"},{"value":[53352705],"title":"Юриспруденция"}]},{"folded":"true","value":null,"name":"direction_bachelor","withNull":1,"hidden":0,"type":"select","class":"select_bachelor","title":"Направление подготовки","items":[{"value":[122397796],"title":"Бизнес-информатика"},{"value":[226164751],"title":"Биология"},{"value":[216490788],"title":"Востоковедение и африканистика"},{"value":[309210162],"title":"География"},{"value":[122326305],"title":"Государственное и муниципальное управление"},{"value":[225719090],"title":"Градостроительство"},{"value":[122472763],"title":"Дизайн"},{"value":[122472768],"title":"Журналистика"},{"value":[210389733],"title":"Зарубежное регионоведение"},{"value":[210420611],"title":"Изящные искусства"},{"value":[122472773],"title":"Инфокоммуникационные технологии и системы связи"},{"value":[122472774],"title":"Информатика и вычислительная техника"},{"value":[226168599],"title":"Информационная безопасность"},{"value":[122326302],"title":"История"},{"value":[122472766],"title":"История искусств"},{"value":[122472777],"title":"Компьютерная безопасность"},{"value":[122472764],"title":"Культурология"},{"value":[135082036],"title":"Лингвистика"},{"value":[122472776],"title":"Математика"},{"value":[135205528],"title":"Медиакоммуникации"},{"value":[122472770],"title":"Международные отношения"},{"value":[122247667],"title":"Менеджмент"},{"value":[122326303],"title":"Политология"},{"value":[122472775],"title":"Прикладная математика"},{"value":[122397795],"title":"Прикладная математика и информатика"},{"value":[122397793],"title":"Программная инженерия"},{"value":[122472772] ...
#   </script>
#   <script src="/f/src/global/node_modules/es6-promise/dist/es6-promise.auto.min.js">
#   </script>
#   <script src="/f/src/global/node_modules/fetch/fetch.js">
#   </script>
#   <script src="/f/src/global/node_modules/classlist-polyfill/src/index.js">
#   </script>
#   <script src="/n/stat/common/common/dist/education/education.js">
#   </script>
#   <script src="/f/src/global/js/education.js">
#   </script>
#  </head>
#  <body data-lang="ru" data-unit="74463">
#   <div class="page">
#    <!--noindex-->
#    <div class="browser_outdate" style="display:none;">
#     В старых версиях браузеров сайт может отображаться некорректно. Для оптимальной работы с сайтом рекомендуем воспользоваться современным браузером.
#    </div>
#    <div class="gdpr_bar" style="display:none;">
#     <div class="gdpr_bar__inner">
#      <noindex>
#       <p>
#        Мы используем файлы cookies для улучшения работы сайта НИУ ВШЭ и большего удобства его использования. Более подробную информацию об использовании файлов cookies можно найти
#        <a href="https://www.hse.ru/cookie.html" rel="nofollow noopener" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        , наши правила обработки персональных данных –
#        <a href="https://www.hse.ru/data_protection_regulation" rel="nofollow noopener" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        . Продолжая пользоваться сайтом, вы подтверждаете, что были проинформированы об использовании файлов cookies сайтом НИУ ВШЭ и согласны с нашими правилами обработки персональных данных. Вы можете отключить файлы cookies в настройках Вашего браузера.
#       </p>
#      </noindex>
#      <span class="gdpr_bar__close">
#       ✖
#      </span>
#     </div>
#    </div>
#    <!--/noindex-->
#    <div class="sv-control">
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-size">
#       <li class="sv-control__item sv-control__item--s_normal active" data-type="size" data-value="normal">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_medium" data-type="size" data-value="medium">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_large" data-type="size" data-value="large">
#        A
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-spacing">
#       <li class="sv-control__item sv-control__item--ls_normal active" data-type="spacing" data-value="normal">
#        АБB
#       </li>
#       <li class="sv-control__item sv-control__item sv-control__item--ls_medium" data-type="spacing" data-value="medium">
#        АБB
#       </li>
#       <li class="sv-control__item sv-control__item--ls_large" data-type="spacing" data-value="large">
#        АБB
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-contrast">
#       <li class="sv-control__item sv-control__item---color1 active" data-type="contrast" data-value="normal">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color2" data-type="contrast" data-value="invert">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color3" data-type="contrast" data-value="blue">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color4" data-type="contrast" data-value="beige">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color5" data-type="contrast" data-value="brown">
#        А
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-image">
#       <li class="sv-control__item sv-control__item--image_on active" data-type="image" data-value="on">
#       </li>
#       <li class="sv-control__item sv-control__item--image_off" data-type="image" data-value="off">
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <div class="sv-off js-sv-off">
#       Обычная версия сайта
#      </div>
#     </div>
#    </div>
#    <header class="header header_dark_gradient">
#     <div class="crop">
#      <div class="header-top header-top--primary">
#       <div class="left">
#        <span class="control control_sitemap">
#         <span class="control_sitemap__line">
#         </span>
#        </span>
#        <a class="control control_home" href="https://www.hse.ru/">
#         <ins>
#          <svg height="26" viewbox="0 0 18 26" width="18" xmlns="http://www.w3.org/2000/svg">
#           <path class="control__path" d="M6.66 0l.134.002h1.336c2.639 0 3.745.464 4.994 1.428 1.819 1.424 2.105 3.492 2.105 4.525 0 1.283-.393 2.638-1.356 3.742-.714.856-1.955 2.097-4.388 2.388-1.663.2-2.891.127-3.506.061v-1.306c.273.038.676.074 1.222.074 1.656 0 2.829-.827 3.543-1.719.81-.983.98-1.909 1.015-2.737h-4.555v-1.282h4.515c-.116-.866-.448-1.528-.985-2.179-1.035-1.283-2.499-1.497-3.462-1.497l-6.505-.002-.768-1.498h6.66zm-6.317 26l.804-1.564v-21.844h3.55v21.82h2.508v-8.523h3.276v8.514h2.838v-3.878c0-2.351-.122-5.622-2.77-7.311l1.542-.566c3.194 1.186 4.791 4.283 4.791 8.362v3.428l.804 1.562h-17.344z" fill="#1658DA">
#           </path>
#          </svg>
#         </ins>
#        </a>
#       </div>
#       <div class="right">
#        <div class="header__controls">
#         <ul class="control_lang2">
#          <li class="control_lang2_item activated">
#           <a class="link link_no-underline" href="https://www.hse.ru/education/">
#            RU
#           </a>
#          </li>
#          <li class="control_lang2_item">
#           <a class="link link_no-underline" href="https://www.hse.ru/en/education/">
#            EN
#           </a>
#          </li>
#         </ul>
#         <span class="control control_vision" title="Версия для слабовидящих">
#          <svg height="12" viewbox="0 0 21 12" width="21" xmlns="http://www.w3.org/2000/svg">
#           <title>
#            Версия для слабовидящих
#           </title>
#           <path class="control__path" d="M10.5 0c3.438 0 6.937 2.016 10.5 6.047-.844.844-1.383 1.375-1.617 1.594-.234.219-.805.703-1.711 1.453-.906.75-1.641 1.266-2.203 1.547-.563.281-1.305.578-2.227.891-.922.313-1.836.469-2.742.469-1.125 0-2.156-.141-3.094-.422-.938-.281-1.875-.766-2.813-1.453-.938-.688-1.672-1.273-2.203-1.758-.531-.484-1.328-1.273-2.391-2.367 2.031-2.031 3.836-3.539 5.414-4.523 1.578-.984 3.273-1.477 5.086-1.477zm0 10.266c1.156 0 2.148-.422 2.977-1.266.828-.844 1.242-1.844 1.242-3s-.414-2.156-1.242-3c-.828-.844-1.82-1.266-2.977-1.266-1.156 0-2.148.422-2.977 1.266-.828.844-1.242 1.844-1.242 3s.414 2.156 1.242 3c.828.844 1.82 1.266 2.977 1.266zm0-5.766c0 .438.141.797.422 1.078s.641.422 1.078.422c.313 0 .625-.109.938-.328v.328c0 .688-.234 1.273-.703 1.758-.469.484-1.047.727-1.734.727-.688 0-1.266-.242-1.734-.727-.469-.484-.703-1.07-.703-1.758s.234-1.273.703-1.758c.469-.484 1.047-.727 1.734-.727h.375c-.25.313-.375.641-.375.984z" fill="#1658DA">
#           </path>
#          </svg>
#         </span>
#         <a class="control control_user" href="https://www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#          <ins>
#           <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Личный кабинет сотрудника ВШЭ
#            </title>
#            <path class="control__path" d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#         </a>
#         <span class="control control_search" title="Поиск">
#          <ins class="popup_opener">
#           <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Поиск
#            </title>
#            <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#          <div class="popup popup_search not_display">
#           <div class="popup__inner">
#            <div class="search-form">
#             <form action="https://www.hse.rusearch/index.html">
#              <div class="search-form__button">
#               <button class="button button_grey">
#                Поиск
#               </button>
#              </div>
#              <div class="search-form__input">
#               <input class="input input100 input_mr" name="text" placeholder="Поиск" type="text"/>
#               <input name="searchid" type="hidden" value="2284688"/>
#               <input name="simple" type="hidden" value="1"/>
#              </div>
#             </form>
#            </div>
#            <div class="popup__block popup__block_indent">
#             <a class="link_dark" href="https://www.hse.ru/search/search.html?simple=0">
#              Расширенный поиск
#             </a>
#             <span class="b-adv-search">
#             </span>
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="control is-mobile control_menu js-control_menu_open" onclick="void(0)">
#          <ins>
#          </ins>
#          <span class="control__text">
#           Меню
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="header_body">
#        <div class="header_breadcrumb is-mobile c">
#         <div class="header_breadcrumb__inner no_crumb_arrow">
#          <a class="header_breadcrumb__link fa-header_body__crumb--first fa-header_body__crumb" href="https://www.hse.ru">
#           Высшая школа экономики
#          </a>
#         </div>
#        </div>
#        <div class="header_breadcrumb is-desktop">
#         <div class="header_breadcrumb__inner no_crumb_arrow js-header_breadcrumb__inner--wide">
#          <ul class="header_breadcrumb__list">
#           <li class="header_breadcrumb__item">
#            <a class="header_breadcrumb__link" href="//www.hse.ru">
#             <span>
#              Национальный исследовательский университет «Высшая школа экономики»
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <span class="header_breadcrumb__current">
#             <span>
#              Образовательные программы НИУ ВШЭ
#             </span>
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header-board js-mobile_popup row">
#       <div class="header-board__top js-mobile_popup__top is-fixed is-mobile">
#        <div class="header-top header-top--secondary">
#         <div class="left">
#          <ul class="control_lang2">
#           <li class="control_lang2_item activated">
#            <a class="link link_no-underline" href="https://www.hse.ru/education/">
#             RU
#            </a>
#           </li>
#           <li class="control_lang2_item">
#            <a class="link link_no-underline" href="https://www.hse.ru/en/education/">
#             EN
#            </a>
#           </li>
#          </ul>
#          <a class="control control_user" href="https://www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#           <ins>
#            <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#             <title>
#              Личный кабинет сотрудника ВШЭ
#             </title>
#             <path class="control__path" d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#             </path>
#            </svg>
#           </ins>
#          </a>
#          <span class="control control_white control_search js-search_mobile_control" title="Поиск">
#           <ins>
#            <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#             <title>
#              Поиск
#             </title>
#             <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#             </path>
#            </svg>
#           </ins>
#          </span>
#         </div>
#         <div class="right">
#          <div class="header__controls">
#           <span class="control is-mobile control_menu control_menu--close js-control_menu_close" onclick="void(0)">
#            <ins>
#            </ins>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="js-search_mobile_popup not_display is-mobile">
#         <div class="search-form">
#          <form action="https://www.hse.ru/education/search/search.html">
#           <div class="search-form__button">
#            <button class="button button_grey">
#             Поиск
#            </button>
#           </div>
#           <div class="search-form__input">
#            <input class="fa-search_input input input100 input_mr" name="text" placeholder="Поиск по сайту" type="text"/>
#            <input name="simple" type="hidden" value="1"/>
#            <input name="searchid" type="hidden" value="2284688"/>
#           </div>
#          </form>
#         </div>
#         <div class="popup__block">
#          <a class="link_white" href="https://www.hse.ru/education/search/search.html?simple=0&amp;searchid=2284688">
#           Расширенный поиск
#          </a>
#         </div>
#        </div>
#        <div class="header-board__title">
#         <a class="link_white link_no-underline" href="https://www.hse.ru/education/">
#          Образовательные программы НИУ ВШЭ
#         </a>
#        </div>
#       </div>
#       <div class="header-board__inner js-mobile_popup__inner b-row b-row--5">
#        <ul class="navigation navigation_header b-row__item">
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/education/faculty">
#           Факультеты и институты
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/education/academ">
#           Академический календарь
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/studyspravka/ras_stud">
#           Расписание пар
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://students.hse.ru/benefits">
#           Программы для лиц с ограниченными возможностями здоровья
#          </a>
#         </li>
#        </ul>
#        <ul class="navigation navigation_header b-row__item">
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://electives.hse.ru/">
#           Выбор траектории обучения
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/sumschool/">
#           Летние школы
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://elearning.hse.ru/mooc">
#           Массовые открытые онлайн-курсы
#          </a>
#         </li>
#        </ul>
#        <ul class="navigation navigation_header b-row__item">
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/edu/courses/">
#           Учебные курсы
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/org/hse/pfair/">
#           Ярмарка проектов
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/edu/vkr/">
#           Выпускные квалификационные работы студентов
#          </a>
#         </li>
#        </ul>
#        <ul class="navigation navigation_header b-row__item">
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://www.hse.ru/scholarships/">
#           Стипендии
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://pay.hse.ru/">
#           Оплата обучения
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a class="navigation__link" href="https://ba.hse.ru/discount">
#           Скидки
#          </a>
#         </li>
#        </ul>
#        <ul class="navigation navigation_header b-row__item">
#         <li class="navigation__item">
#          <p class="small">
#           <a class="pretty-button pretty-button_violet link link_no-underline" href="https://ba.hse.ru">
#            <noindex>
#             <span class="link link_white">
#              Поступающим
#             </span>
#            </noindex>
#           </a>
#          </p>
#          <p class="small">
#           <a href="https://school.hse.ru">
#            В лицей
#           </a>
#           <br/>
#           <a href="https://ba.hse.ru">
#            В бакалавриат
#           </a>
#           <br/>
#           <a href="https://ma.hse.ru">
#            В магистратуру
#           </a>
#           <br/>
#           <a href="https://aspirantura.hse.ru">
#            В аспирантуру
#           </a>
#          </p>
#          <p>
#           <a class="pretty-button pretty-button_violet link link_no-underline" href="https://admissions.hse.ru/">
#            <span class="link link_white">
#             Иностранным абитуриентам
#            </span>
#           </a>
#          </p>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="crop">
#     <div class="folder__decor folder__decor folder__decor_apple">
#     </div>
#     <div class="folder__decor folder__decor folder__decor_marker">
#     </div>
#     <div class="folder__decor folder__decor folder__decor_ears">
#     </div>
#    </div>
#    <div class="layout has-sidebar">
#     <div class="grid grid_3">
#      <div class="wrapper row">
#       <div class="sidebar">
#        <div class="sidebar__inner">
#         <div class="filter js-mobile_secondary_popup">
#          <div class="filter__top js-mobile_popup__top is-fixed is-mobile">
#           <div class="filter__caption">
#            Фильтры
#           </div>
#           <div class="filter__close is-mobile pseudo js-control_secondary_menu_close">
#           </div>
#          </div>
#          <div id="b-side__filters">
#          </div>
#          <div class="with-indent button button_clean button_medium c js-control_secondary_menu_close is-mobile">
#           Применить
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="main">
#       <div class="content">
#        <div class="content__inner">
#         <div class="edu-programm_top">
#          <h1>
#           Программы бакалавриата НИУ ВШЭ в Москве
#          </h1>
#          <div class="lead-in with-indent">
#           <p>
#            Высшая школа экономики — это отличный старт для карьеры в бизнесе, на государственной службе и в науке. Здесь готовят высококлассных специалистов, нужных стране.
#           </p>
#          </div>
#          <div class="b-row with-indent2">
#           <div class="b-row__item b-row__item--m9 u-rel">
#            <button class="js-select_button pseudo">
#             Бакалавриат
#            </button>
#            <ul class="navigation navigation_horizontal navigation_tab navigation_tab_violet b small js-select_list edu-switcher">
#             <li class="navigation_item for_undefined">
#              <a class="pseudo link_dark link" href="//shkolnikam.hse.ru">
#               Школьникам
#              </a>
#             </li>
#             <li class="navigation_item for_undefined">
#              <a class="pseudo link_dark link" href="//school.hse.ru">
#               Лицей
#              </a>
#             </li>
#             <li class="bachelor selected for_bachelor" data-type="bachelor">
#              <span class="pseudo link_dark pseudo_link js-pseudo">
#               Бакалавриат
#              </span>
#             </li>
#             <li class="magister for_magister" data-type="magister">
#              <span class="pseudo link_dark pseudo_link js-pseudo">
#               Магистратура
#              </span>
#             </li>
#             <li class="navigation_item for_undefined">
#              <a class="pseudo link_dark link" href="http://busedu.hse.ru/">
#               Дополнительное и бизнес-образование
#              </a>
#             </li>
#             <li class="navigation_item for_undefined">
#              <a class="pseudo link_dark link" href="https://elearning.hse.ru/mooc/">
#               Онлайн-курсы
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="b-row__item is-mobile b-row__item--m3 b-row__item--middle">
#            <span class="link link_pseudo small js-m_filter">
#             Фильтр
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="search-form search-form_results search-form-programmes with-indent6" style="padding-left: 30px;">
#          <input class="input input100 input_search search-form-programmes__value" placeholder="Поиск по образовательным программам" type="search"/>
#         </div>
#         <div data-real-unit="150756470" id="education-programs__list">
#          <div class="edu-programm__tab edu-programm__bachelor">
#           <div class="edu-programm__group">
#            <h3 class="u-accent u normal with-indent4 edu-programm__caption">
#             07.00.00 Архитектура
#            </h3>
#            <div class="b-row edu-programm__item" data-filters='[225719090,51999662,221942181,"07.00.00 Архитектура","ruen","b","p","pf","full","Городское планирование","mathematics","socscience","rl"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/up/">
#               Городское планирование
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Факультет городского и регионального развития
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                35/40/10
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 35 бюджетных
#                </div>
#                <div class="with-indent1">
#                 40 платных
#                </div>
#                <div class="with-indent1">
#                 10 платных мест для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               490 000 руб. в год
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="edu-programm__group">
#            <h3 class="u-accent u normal with-indent4 edu-programm__caption">
#             06.00.00 Биологические науки
#            </h3>
#            <div class="b-row edu-programm__item" data-filters='[226164751,51999662,226090865,"06.00.00 Биологические науки","ruen","b","p","pf","full","Клеточная и молекулярная биотехнология","biology","mathematics","rl","chemistry"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/cmb/">
#               Клеточная и молекулярная биотехнология
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Факультет биологии и биотехнологии
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               4 года
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                23/10/10
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 23 бюджетных
#                </div>
#                <div class="with-indent1">
#                 10 платных
#                </div>
#                <div class="with-indent1">
#                 10 платных мест для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               440 000 руб. в год
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="edu-programm__group">
#            <h3 class="u-accent u normal with-indent4 edu-programm__caption">
#             58.00.00 Востоковедение и африканистика
#            </h3>
#            <div class="b-row edu-programm__item" data-filters='[216490788,51999662,208095182,"58.00.00 Востоковедение и африканистика","ruen","b","p","pf","full","Арабистика: язык, словесность, культура","fl","history","rl"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/arabic/">
#               Арабистика: язык, словесность, культура
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Институт классического Востока и античности
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                10/5/1
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 10 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#                <div class="with-indent1">
#                 1 платное место для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               440 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[216490788,216490788,51999662,22750,"58.00.00 Востоковедение и африканистика","ruen","b","p","pf","full","Востоковедение","history","fl","rl"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/oriental/">
#               Востоковедение
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Факультет мировой экономики и мировой политики
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                49/80/10
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 49 бюджетных
#                </div>
#                <div class="with-indent1">
#                 80 платных
#                </div>
#                <div class="with-indent1">
#                 10 платных мест для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               490 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[216490788,216490788,51999665,133639230,"58.00.00 Востоковедение и африканистика","ruen","b","p","pf","full","Востоковедение","history","fl","rl"]' style="display: none;">
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://spb.hse.ru/ba/oriental/">
#               Востоковедение
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-spb">
#                Санкт-Петербург
#               </span>
#               <span class="grey">
#                Санкт-Петербургская школа социальных наук и востоковедения
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                23/90/10
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 23 бюджетных
#                </div>
#                <div class="with-indent1">
#                 90 платных
#                </div>
#                <div class="with-indent1">
#                 10 платных мест для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               450 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[216490788,51999662,208095182,"58.00.00 Востоковедение и африканистика","ruen","b","p","pf","full","Христианский Восток","fl","history","rl"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/christian/">
#               Христианский Восток
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Институт классического Востока и античности
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                10/5/1
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 10 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#                <div class="with-indent1">
#                 1 платное место для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               440 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[216490788,51999662,208095182,"58.00.00 Востоковедение и африканистика","ruen","b","p","pf","full","Язык, словесность и культура Китая","fl","history","rl"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ba/chinese/">
#               Язык, словесность и культура Китая
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Институт классического Востока и античности
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               5 лет
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                10/5/1
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 10 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#                <div class="with-indent1">
#                 1 платное место для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               440 000 руб. в год
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="edu-programm__group">
#            <h3 class="u-accent u normal with-indent4 edu-programm__caption">
#             54.00.00 Изобразительное искусство и прикладные виды искусств
#            </h3>
#            <div class="b-row edu-programm__item" data-filters='[122472763,51999662,119384956,122999274,"54.00.00 Изобразительное искусство и прикладные виды искусств","ruen","b","p","pf","full","Дизайн","crcmp","rl","literature"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://design.hse.ru/ba/program/design">
#               Дизайн
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Факультет коммуникаций, медиа и дизайна, Школа дизайна
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               4 года
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                52/300/30
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 52 бюджетных
#                </div>
#                <div class="with-indent1">
#                 300 платных
#                </div>
# ...
#                 20 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               300 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[53352697,51999662,141971113,"45.00.00 Языкознание и литературоведение","ruen","b","p","full","Цифровые методы в гуманитарных науках"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ma/dh/">
#               Цифровые методы в гуманитарных науках
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Школа лингвистики
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               2 года
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                20/5
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 20 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               390 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[138534234,51999662,139191145,"45.00.00 Языкознание и литературоведение","ruen","b","p","pf","full","Языковая политика в условиях этнокультурного разнообразия"]'>
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://www.hse.ru/ma/langpolicy/">
#               Языковая политика в условиях этнокультурного разнообразия
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-msk">
#                Москва
#               </span>
#               <span class="grey">
#                Факультет гуманитарных наук
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               2 года
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                15/5/5
#               </div>
#               <div class="tooltip">
#                <div class="edu-programm__place_free">
#                 15 бюджетных
#                </div>
#                <div class="with-indent1">
#                 5 платных
#                </div>
#                <div class="with-indent1">
#                 5 платных мест для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               390 000 руб. в год
#              </div>
#             </div>
#            </div>
#            <div class="b-row edu-programm__item" data-filters='[53352697,51999665,222569607,"45.00.00 Языкознание и литературоведение","ruen","p","pf","full","Языковые технологии в бизнесе и образовании"]' style="display: none;">
#             <div class="b-row__item b-row__item--6 b-row__item--t12">
#              <a class="link" href="https://spb.hse.ru/ma/language/">
#               Языковые технологии в бизнесе и образовании
#              </a>
#              <div class="edu-programm__unit">
#               <span class="edu-programm__city with-icon with-icon_flag-spb">
#                Санкт-Петербург
#               </span>
#               <span class="grey">
#                Санкт-Петербургская школа гуманитарных наук и искусств
#               </span>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#              <div class="edu-programm__data u-accent">
#               2 года
#              </div>
#              <div class="edu-programm__edu_offline">
#               Очная
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#              <div class="b-row__item--place">
#               <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#                13/2
#               </div>
#               <div class="tooltip">
#                <div class="with-indent1">
#                 13 платных
#                </div>
#                <div class="with-indent1">
#                 2 платных места для иностранцев
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#              <div class="edu-programm__data u-accent">
#               270 000 руб. в год
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer class="footer">
#     <div class="footer__border">
#     </div>
#     <div class="footer__inner row">
#      <div class="fa-footer">
#       <div class="fa-footer__menu">
#        <div class="fa-footer__menu_inner b-row b-row--4">
#         <ul class="navigation b-row__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="">
#            Москва
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://school.hse.ru/">
#            Лицей НИУ ВШЭ
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://gsb.hse.ru/">
#            Высшая школа бизнеса
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://law.hse.ru/">
#            Высшая школа юриспруденции и администрирования
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://issek.hse.ru/">
#            Институт статистических исследований и экономики знаний
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://biology.hse.ru/">
#            Факультет биологии и биотехнологии
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://geography.hse.ru/">
#            Факультет географии и геоинформационных технологий
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://gorod.hse.ru/">
#            Факультет городского и регионального развития
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://hum.hse.ru/">
#            Факультет гуманитарных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://cs.hse.ru/">
#            Факультет компьютерных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://cmd.hse.ru/">
#            Факультет коммуникаций, медиа и дизайна
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://math.hse.ru/">
#            Факультет математики
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://we.hse.ru/">
#            Факультет мировой экономики и мировой политики
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://pravo.hse.ru/">
#            Факультет права
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://social.hse.ru/">
#            Факультет социальных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://physics.hse.ru/">
#            Факультет физики
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://chemistry.hse.ru/">
#            Факультет химии
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://economics.hse.ru/">
#            Факультет экономических наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://icef.hse.ru/">
#            Международный институт экономики и финансов
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://miem.hse.ru/">
#            Московский институт электроники и математики им. А.Н. Тихонова
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation b-row__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="">
#            Нижний Новгород
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://nnov.hse.ru/bipm/">
#            Факультет информатики, математики и компьютерных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://nnov.hse.ru/human/">
#            Факультет гуманитарных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://nnov.hse.ru/management/">
#            Факультет менеджмента
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://nnov.hse.ru/nnlaw/">
#            Факультет права
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://nnov.hse.ru/economics/">
#            Факультет экономики
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation b-row__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="">
#            Пермь
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://perm.hse.ru/bi/">
#            Факультет экономики, менеджмента и бизнес-информатики
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://perm.hse.ru/sgf">
#            Социально-гуманитарный факультет
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation b-row__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="">
#            Санкт-Петербург
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://spb.hse.ru/humart/">
#            Санкт-Петербургская школа гуманитарных наук и искусств
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://spb.hse.ru/soc">
#            Санкт-Петербургская школа социальных наук и востоковедения
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://spb.hse.ru/fmcs/">
#            Санкт-Петербургская школа физико-математических и компьютерных наук
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://spb.hse.ru/scem/">
#            Санкт-Петербургская школа экономики и менеджмента
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://spb.hse.ru/ius/">
#            Юридический факультет
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <!--noindex-->
#      <div class="fa-footer__menu with-indent3">
#       <ul class="ul b-row b-row--6">
#        <li class="b-row__item">
#         <a href="http://www.minobrnauki.gov.ru/" rel="nofollow">
#          http://www.minobrnauki.gov.ru/
#         </a>
#         <div>
#          Министерство науки и высшего образования РФ
#         </div>
#        </li>
#        <li class="b-row__item">
#         <a href="https://edu.gov.ru/" rel="nofollow">
#          https://edu.gov.ru/
#         </a>
#         <div>
#          Министерство просвещения РФ
#         </div>
#        </li>
#        <li class="b-row__item">
#         <a href="http://www.edu.ru" rel="nofollow">
#          http://www.edu.ru
#         </a>
#         <div>
#          Федеральный портал «Российское образование»
#         </div>
#        </li>
#        <li class="b-row__item">
#         <a href="https://elearning.hse.ru/mooc" rel="nofollow">
#          https://elearning.hse.ru/mooc
#         </a>
#         <div>
#          Массовые открытые онлайн-курсы
#         </div>
#        </li>
#        <li class="b-row__item">
#         <a href="http://5top100.ru/" rel="nofollow">
#          http://5top100.ru/
#         </a>
#         <div>
#          Проект 5-100
#         </div>
#        </li>
#        <li class="b-row__item">
#         <a href="https://studyinrussia.ru/" rel="nofollow">
#          https://studyinrussia.ru/
#         </a>
#         <div>
#          Study In Russia
#         </div>
#        </li>
#       </ul>
#      </div>
#      <!--/noindex-->
#      <div class="fa-footer__menu with-indent3 b-row">
#       <ul class="ul b-row__item b-row__item--9 small navigation navigation_horizontal">
#        <li class="navigation__item">
#         <span class="fa-grey">
#          ©  НИУ ВШЭ 1993–2021
#         </span>
#        </li>
#        <li class="navigation__item">
#         <a href="https://www.hse.ru/contacts.html">
#          Адреса и контакты
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a href="https://www.hse.ru/copyright">
#          Условия использования материалов
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a href="https://www.hse.ru/data_protection_regulation">
#          Политика конфиденциальности
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a href="https://www.hse.ru/sitemap.html">
#          Карта сайта
#         </a>
#        </li>
#       </ul>
#       <!--noindex-->
#       <div class="b-row__item b-row__item--3 small">
#        <a class="link_dashed link_editor link_btm_editor" href="https://www.hse.ru/adm/edit/edit.html?goto=%2AL2VkdWNhdGlvbi9tc2svYmFjaGVsb3IvP19yPTMzMzI5ODExNjI2Nzc5NjIxLjcwOTI5%5E&amp;id=150756470&amp;cid=22700&amp;addon_name=default&amp;newportal=1" rel="nofollow">
#         Редактору
#        </a>
#       </div>
#       <!--/noindex-->
#      </div>
#     </div>
#    </footer>
#   </div>
#  </body>
# </html>

# %% [markdown]
# Получим список всех образовательных программ и соотвествующих им факультетов, а также ссылки на страницы с описанием программ.
# Для этого методом пристального взгляда найдем в html-коде выше ```div```-ы с нужными полями ```id``` и ```class``` и пройдемся по ним:

# %%
programs_html = soup('div', id='education-programs__list')[0]
programs = programs_html('div', 'edu-programm__item')
for program in programs:
    faculty = program('div', 'edu-programm__unit')[0]('span')[1].text
    name = program.a.text
    url = program.a['href']
    print(faculty, name, url, sep=' | ')
# Out:
# Факультет городского и регионального развития | Городское планирование | https://www.hse.ru/ba/up/
# Факультет биологии и биотехнологии | Клеточная и молекулярная биотехнология | https://www.hse.ru/ba/cmb/
# Институт классического Востока и античности | Арабистика: язык, словесность, культура | https://www.hse.ru/ba/arabic/
# Факультет мировой экономики и мировой политики | Востоковедение | https://www.hse.ru/ba/oriental/
# Санкт-Петербургская школа социальных наук и востоковедения | Востоковедение | https://spb.hse.ru/ba/oriental/
# Институт классического Востока и античности | Христианский Восток | https://www.hse.ru/ba/christian/
# Институт классического Востока и античности | Язык, словесность и культура Китая | https://www.hse.ru/ba/chinese/
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Дизайн | https://design.hse.ru/ba/program/design
# Школа дизайна, Санкт-Петербургская школа гуманитарных наук и искусств | Дизайн | https://spb.hse.ru/ba/designs/
# Факультет гуманитарных наук | Дизайн | https://nnov.hse.ru/ba/design/
# Социально-гуманитарный факультет | Дизайн | https://perm.hse.ru/ba/design/
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Мода | https://design.hse.ru/ba/program/fashion
# Московский институт электроники и математики им. А.Н. Тихонова | Информатика и вычислительная техника | https://www.hse.ru/ba/isct/
# Факультет компьютерных наук | Программная инженерия | https://www.hse.ru/ba/se/
# Факультет информатики, математики и компьютерных наук | Программная инженерия | https://nnov.hse.ru/ba/se/
# Факультет экономики, менеджмента и бизнес-информатики | Программная инженерия | https://perm.hse.ru/ba/se/
# Московский институт электроники и математики им. А.Н. Тихонова, Департамент электронной инженерии | Информационная безопасность | https://www.hse.ru/ba/is/
# Московский институт электроники и математики им. А.Н. Тихонова | Компьютерная безопасность | https://www.hse.ru/ba/cosec/
# Факультет гуманитарных наук | История искусств | https://www.hse.ru/ba/histart/
# Факультет коммуникаций, медиа и дизайна | Современное искусство | https://art.hse.ru/ba
# Институт классического Востока и античности | Античность | https://www.hse.ru/ba/antiq/
# Факультет гуманитарных наук | История | https://www.hse.ru/ba/hist/
# Санкт-Петербургская школа гуманитарных наук и искусств | История | https://spb.hse.ru/ba/hist/
# Социально-гуманитарный факультет | История | https://perm.hse.ru/ba/hist/
# Факультет гуманитарных наук | Культурология | https://www.hse.ru/ba/cultural/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Анализ данных в финансах | https://spb.hse.ru/ba/dataanalytics/
# Факультет компьютерных наук | Компьютерные науки и анализ данных | https://www.hse.ru/ba/compds/
# Факультет математики | Математика | https://www.hse.ru/ba/math/
# Факультет информатики, математики и компьютерных наук | Математика | https://nnov.hse.ru/ba/math/
# Московский институт электроники и математики им. А.Н. Тихонова | Прикладная математика | https://www.hse.ru/ba/am/
# Факультет компьютерных наук | Прикладная математика и информатика | https://www.hse.ru/ba/ami/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Прикладная математика и информатика | https://spb.hse.ru/ba/appmath/
# Факультет информатики, математики и компьютерных наук | Прикладная математика и информатика | https://nnov.hse.ru/ba/ami/
# Факультет компьютерных наук | Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных» | https://www.hse.ru/ba/data/
# Факультет математики | Совместный бакалавриат НИУ ВШЭ и ЦПМ | https://www.hse.ru/ba/cpm/
# Факультет географии и геоинформационных технологий | География глобальных изменений и геоинформационные технологии | https://www.hse.ru/ba/geography/
# Факультет мировой экономики и мировой политики | Международные отношения | https://www.hse.ru/ba/ia/
# Факультет социальных наук | Политология | https://www.hse.ru/ba/political/
# Санкт-Петербургская школа социальных наук и востоковедения | Политология и мировая политика | https://spb.hse.ru/ba/political/
# Факультет мировой экономики и мировой политики | Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям | https://www.hse.ru/ba/ir/
# Факультет мировой экономики и мировой политики | Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям | https://www.hse.ru/ba/ir/
# Факультет мировой экономики и мировой политики | Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии» | https://www.hse.ru/ba/epa/
# Факультет социальных наук | Психология | https://www.hse.ru/ba/psy/
# Факультет социальных наук | Социология | https://www.hse.ru/ba/soc/
# Санкт-Петербургская школа социальных наук и востоковедения | Социология и социальная информатика | https://spb.hse.ru/ba/soc/
# Факультет коммуникаций, медиа и дизайна | Журналистика | https://www.hse.ru/ba/journ/
# Факультет коммуникаций, медиа и дизайна | Медиакоммуникации | https://www.hse.ru/ba/media/
# Факультет коммуникаций, медиа и дизайна | Реклама и связи с общественностью | https://www.hse.ru/ba/ad/
# Факультет физики | Физика | https://www.hse.ru/ba/physics/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Физика | https://spb.hse.ru/ba/physics/
# Факультет гуманитарных наук | Философия | https://www.hse.ru/ba/phil/
# Факультет химии | Химия | https://www.hse.ru/ba/chem/
# Высшая школа бизнеса | Бизнес-информатика | https://www.hse.ru/ba/bi/
# Факультет информатики, математики и компьютерных наук | Бизнес-информатика | https://nnov.hse.ru/ba/bi/
# Факультет экономики, менеджмента и бизнес-информатики | Бизнес-информатика | https://perm.hse.ru/ba/bi/
# Факультет социальных наук | Государственное и муниципальное управление | https://www.hse.ru/ba/gmu/
# Высшая школа бизнеса | Логистика и управление цепями поставок | https://www.hse.ru/ba/logistics/
# Санкт-Петербургская школа экономики и менеджмента | Логистика и управление цепями поставок | https://spb.hse.ru/ba/log/
# Высшая школа бизнеса | Маркетинг и рыночная аналитика | https://www.hse.ru/ba/marketing/
# Санкт-Петербургская школа экономики и менеджмента | Международный бизнес и менеджмент/ Менеджмент | https://spb.hse.ru/ba/management/
# Факультет мировой экономики и мировой политики | Мировая экономика | https://www.hse.ru/ba/we/
# Международный институт экономики и финансов | Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета | https://www.hse.ru/ba/icef/
# Факультет экономических наук | Совместная программа по экономике НИУ ВШЭ и РЭШ | https://www.hse.ru/ba/nes/
# Высшая школа бизнеса | Управление бизнесом | https://www.hse.ru/ba/bba/
# Факультет менеджмента | Управление бизнесом | https://nnov.hse.ru/ba/business/
# Факультет экономики, менеджмента и бизнес-информатики | Управление бизнесом | https://perm.hse.ru/ba/business/
# Санкт-Петербургская школа социальных наук и востоковедения | Управление и аналитика в государственном секторе | https://spb.hse.ru/ba/gmu/
# Высшая школа бизнеса | Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета) | https://www.hse.ru/ba/digital/
# Факультет экономических наук | Экономика | https://www.hse.ru/ba/economics/
# Санкт-Петербургская школа экономики и менеджмента | Экономика | https://spb.hse.ru/ba/economics/
# Факультет экономики НИУ ВШЭ | Экономика | https://nnov.hse.ru/ba/economics/
# Факультет экономики, менеджмента и бизнес-информатики | Экономика | https://perm.hse.ru/ba/economics/
# Факультет экономических наук | Экономика и статистика | https://www.hse.ru/ba/stat/
# Московский институт электроники и математики им. А.Н. Тихонова, Департамент электронной инженерии | Инфокоммуникационные технологии и системы связи | https://www.hse.ru/ba/it/
# Факультет права | Юриспруденция | https://www.hse.ru/ba/law/
# Юридический факультет | Юриспруденция | https://spb.hse.ru/ba/law/
# Факультет права | Юриспруденция | https://nnov.hse.ru/ba/law/
# Социально-гуманитарный факультет | Юриспруденция | https://perm.hse.ru/ba/law/
# Факультет права | Юриспруденция: частное право | https://www.hse.ru/ba/privlaw/
# Институт классического Востока и античности | Античность | https://www.hse.ru/ba/antiq/
# Школа иностранных языков | Иностранные языки и межкультурная коммуникация | https://www.hse.ru/ba/lang/
# Социально-гуманитарный факультет | Иностранные языки и межкультурная коммуникация в бизнесе | https://perm.hse.ru/ba/communication/
# Факультет гуманитарных наук | Филология | https://www.hse.ru/ba/philology/
# Санкт-Петербургская школа гуманитарных наук и искусств | Филология | https://spb.hse.ru/ba/philology/
# Факультет гуманитарных наук | Филология | https://nnov.hse.ru/ba/philology/
# Факультет гуманитарных наук | Фундаментальная и компьютерная лингвистика | https://www.hse.ru/ba/ling/
# Факультет гуманитарных наук | Фундаментальная и прикладная лингвистика | https://nnov.hse.ru/ba/ling/
# Высшая школа урбанистики имени А.А. Высоковского | Управление пространственным развитием городов | https://www.hse.ru/ma/urban/
# Санкт-Петербургская школа социальных наук и востоковедения | Бизнес и политика в современной Азии | https://spb.hse.ru/ma/econasia/
# Факультет мировой экономики и мировой политики | Социально-экономическое и политическое развитие современной Азии | https://www.hse.ru/ma/asia/
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Дизайн | http://design.hse.ru/mag-design
# Факультет коммуникаций, медиа и дизайна | Дизайн интерьера | https://design.hse.ru/ma/program/interior
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Коммуникационный и цифровой дизайн | http://design.hse.ru/mag-comm
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Мода | http://design.hse.ru/mag-fashion
# Московский институт электроники и математики им. А.Н. Тихонова | Компьютерные системы и сети | https://www.hse.ru/ma/system/
# Факультет компьютерных наук | Системная и программная инженерия | https://www.hse.ru/ma/se/
# Факультет компьютерных наук | Системное программирование | https://www.hse.ru/ma/sp/
# Московский институт электроники и математики им. А.Н. Тихонова | Информационная безопасность киберфизических систем | https://www.hse.ru/ma/cyber/
# Факультет гуманитарных наук | История художественной культуры и рынок искусства | https://www.hse.ru/ma/art/
# Базовая кафедра Музея современного искусства «Гараж» | Практики кураторства в современном искусстве | https://www.hse.ru/ma/curator/
# Школа дизайна | Практики современного искусства | http://art.hse.ru/ma
# Институт классического Востока и античности | Античная и восточная археология | https://www.hse.ru/ma/aea/
# Санкт-Петербургская школа гуманитарных наук и искусств | Глобальная и региональная история / Global and Regional History | https://spb.hse.ru/ma/grhistory/
# Факультет гуманитарных наук | История современного мира | https://www.hse.ru/ma/socialhist/
# Факультет гуманитарных наук | Медиевистика | https://www.hse.ru/ma/medieval/
# Факультет гуманитарных наук | Мусульманские миры в России (История и культура) | https://www.hse.ru/ma/mw/
# Факультет гуманитарных наук | Современная историческая наука в преподавании истории в школе | https://www.hse.ru/ma/irin/
# Социально-гуманитарный факультет | Цифровые методы в гуманитарных науках | https://perm.hse.ru/ma/digitalhum/
# Факультет гуманитарных наук | Визуальная культура | https://www.hse.ru/ma/visual/
# Факультет гуманитарных наук | Культурная и интеллектуальная история: между Востоком и Западом | https://www.hse.ru/ma/inhist/
# Факультет гуманитарных наук | Прикладная культурология | https://www.hse.ru/ma/cult/
# Факультет компьютерных наук | Анализ данных в биологии и медицине | https://www.hse.ru/ma/adbm/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Вычислительная биология и биоинформатика | https://spb.hse.ru/ma/bioinformatics/
# Факультет информатики, математики и компьютерных наук | Интеллектуальный анализ данных | https://nnov.hse.ru/ma/data/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Информационные системы и взаимодействие человек-компьютер | https://spb.hse.ru/ma/computer/
# Факультет информатики, математики и компьютерных наук | Магистр по компьютерному зрению | https://nnov.hse.ru/ma/vision/
# Факультет компьютерных наук | Магистр по наукам о данных | https://www.hse.ru/ma/mds/
# Международная лаборатория прикладного сетевого анализа | Магистр прикладной и сетевой аналитики | https://www.hse.ru/ma/dataanalytics/
# Факультет математики | Математика | https://www.hse.ru/ma/math/
# Факультет информатики, математики и компьютерных наук | Математика | https://nnov.hse.ru/ma/math/
# Факультет математики | Математика и математическая физика | https://www.hse.ru/ma/pmath/
# Факультет компьютерных наук | Математика машинного обучения | https://www.hse.ru/ma/sltheory/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Машинное обучение и анализ данных | https://spb.hse.ru/ma/ml/
# Факультет компьютерных наук | Машинное обучение и высоконагруженные системы | https://www.hse.ru/ma/mlds/
# Факультет компьютерных наук | Науки о данных | https://www.hse.ru/ma/datasci/
# Международная лаборатория прикладного сетевого анализа, Факультет социальных наук | Прикладная статистика с методами сетевого анализа | https://www.hse.ru/ma/sna/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Программирование и анализ данных | https://spb.hse.ru/ma/data/
# Московский институт электроники и математики им. А.Н. Тихонова | Системный анализ и математические технологии | https://www.hse.ru/ma/samt/
# Факультет математики | Совместная магистратура НИУ ВШЭ и ЦПМ | https://www.hse.ru/ma/cpm/
# Факультет компьютерных наук | Финансовые технологии и анализ данных | https://www.hse.ru/ma/fintech/
# Институт образования | Педагогическое образование | https://www.hse.ru/ma/teach/
# Школа дизайна | Современный дизайн в преподавании изобразительного искусства и технологии в школе | http://design.hse.ru/pages/184
# Факультет гуманитарных наук | Germanica: история и современность | https://www.hse.ru/ma/germanica/
# Санкт-Петербургская школа социальных наук и востоковедения | Анализ данных для государства и общества | https://spb.hse.ru/ma/daps/
# Факультет мировой экономики и мировой политики | Международные отношения в Евразии | https://www.hse.ru/ma/eurasia/
# Факультет мировой экономики и мировой политики | Международные отношения: европейские и азиатские исследования | https://www.hse.ru/ma/irmaster/
# Факультет социальных наук | Политика. Экономика. Философия | https://www.hse.ru/ma/pep/
# Кафедра публичной политики | Политический анализ и публичная политика / Political Analysis and Public Policy | https://www.hse.ru/ma/politanaliz/
# Факультет социальных наук | Прикладная политология | https://www.hse.ru/ma/ps/
# Факультет социальных наук | Современные социальные науки в преподавании обществознания в школе | https://www.hse.ru/ma/mps/
# Санкт-Петербургская школа социальных наук и востоковедения | Сравнительная политика Евразии | https://spb.hse.ru/ma/pm/
# Санкт-Петербургская школа социальных наук и востоковедения | Сравнительная политика России и Евразии | https://spb.hse.ru/ma/eurasia/
# Факультет мировой экономики и мировой политики | Экономика, политика и бизнес в Азии / Economics, politics and business in Asia | https://www.hse.ru/ma/epba/
# Факультет биологии и биотехнологии | Биоэкономика | https://www.hse.ru/ma/bioeconomics/
# Институт когнитивных нейронаук | Когнитивные науки и технологии: от нейрона к познанию | https://www.hse.ru/ma/cogito/
# Факультет социальных наук | Консультативная психология. Персонология | https://www.hse.ru/ma/consult/
# Институт образования | Обучение и оценивание как наука | https://www.hse.ru/ma/sla/
# Факультет социальных наук | Позитивная психология | https://www.hse.ru/ma/positive/
# Факультет социальных наук | Прикладная социальная психология | https://www.hse.ru/ma/socpsy/
# Факультет социальных наук | Психоанализ и психоаналитическая психотерапия | https://www.hse.ru/ma/therapy/
# Факультет социальных наук | Психоанализ и психоаналитическое бизнес-консультирование | https://www.hse.ru/ma/psyan/
# Факультет социальных наук | Психология в бизнесе | https://www.hse.ru/ma/pb/
# Факультет социальных наук | Системная семейная психотерапия | https://www.hse.ru/ma/family/
# Институт демографии имени А.Г. Вишневского | Демография | https://www.hse.ru/ma/demography/
# Факультет социальных наук | Комплексный социальный анализ | https://www.hse.ru/ma/csa/
# Факультет социальных наук | Прикладные методы социального анализа рынков | https://www.hse.ru/ma/msa/
# Санкт-Петербургская школа социальных наук и востоковедения | Современный социальный анализ | https://spb.hse.ru/ma/msa/
# Факультет социальных наук | Социология публичной и деловой сферы | https://www.hse.ru/ma/public/
# Факультет социальных наук | Сравнительные социальные исследования / Comparative Social Research | https://www.hse.ru/ma/csr/
# Высшая школа юриспруденции и администрирования | Международное и национальное спортивное право | https://www.hse.ru/ma/sportslaw/
# Высшая школа юриспруденции и администрирования | Международный спортивный менеджмент и маркетинг | https://www.hse.ru/ma/insport/
# Факультет коммуникаций, медиа и дизайна | Журналистика данных | https://www.hse.ru/ma/datajourn/
# Факультет коммуникаций, медиа и дизайна | Интегрированные коммуникации | https://www.hse.ru/ma/incom/
# Факультет коммуникаций, медиа и дизайна | Кинопроизводство в мультиплатформенной среде | https://www.hse.ru/ma/kino/
# Факультет коммуникаций, медиа и дизайна | Коммуникации в государственных структурах и НКО | https://www.hse.ru/ma/communicate/
# Факультет коммуникаций, медиа и дизайна | Коммуникации, основанные на данных | https://www.hse.ru/ma/bigcomm/
# Факультет коммуникаций, медиа и дизайна | Критические медиаисследования / Critical media studies | https://www.hse.ru/ma/cms/
# Санкт-Петербургская школа гуманитарных наук и искусств | Медиапроизводство и медиааналитика | https://spb.hse.ru/ma/man/
# Факультет коммуникаций, медиа и дизайна | Менеджмент в СМИ | https://www.hse.ru/ma/media/
# Факультет коммуникаций, медиа и дизайна | Производство новостей в международной среде | https://www.hse.ru/ma/innews/
# Факультет коммуникаций, медиа и дизайна | Трансмедийное производство в цифровых индустриях | https://www.hse.ru/ma/digital/
# Кафедра менеджмента инноваций | Управление исследованиями, разработками и инновациями в компании | https://www.hse.ru/ma/rdi/
# Факультет физики | Физика | https://www.hse.ru/ma/fizika/
# Санкт-Петербургская школа физико-математических и компьютерных наук | Физика | https://spb.hse.ru/ma/tmphysics/
# Факультет гуманитарных наук | Философия и история религии | https://www.hse.ru/ma/relhist/
# Факультет гуманитарных наук | Философская антропология | https://www.hse.ru/ma/philosophical/
# Факультет экономики, менеджмента и бизнес-информатики | Smart-маркетинг: данные, аналитика, инсайты | https://perm.hse.ru/ma/smart/
# Факультет экономических наук | Аграрная экономика | https://www.hse.ru/ma/agri/
# Институт проблем безопасности | Аналитик деловой разведки | https://www.hse.ru/ma/intelligence/
# Высшая школа бизнеса | Бизнес-аналитика и системы больших данных | https://www.hse.ru/ma/bigdata/
# Факультет информатики, математики и компьютерных наук | Бизнес-информатика | https://nnov.hse.ru/ma/bi/
# Высшая школа бизнеса | Бизнес-информатика: цифровое предприятие и управление информационными системами | https://www.hse.ru/ma/bi/
# Санкт-Петербургская школа социальных наук и востоковедения | Городское развитие и управление | https://spb.hse.ru/ma/gmu/
# Факультет социальных наук | Государственное и муниципальное управление | https://www.hse.ru/ma/gmu/
# Факультет экономики, менеджмента и бизнес-информатики | Государственное и муниципальное управление | https://perm.hse.ru/ma/gmu/
#  | Демография | https://www.hse.ru/ma/demography/
# Институт образования | Доказательное развитие образования | https://www.hse.ru/ma/education/
# Факультет экономики, менеджмента и бизнес-информатики | Информационная аналитика в управлении предприятием | https://perm.hse.ru/ma/iaem/
# Факультет экономических наук | Корпоративные финансы | https://www.hse.ru/ma/cf/
# Факультет экономических наук | Магистр аналитики бизнеса | https://www.hse.ru/ma/mba/
# Факультет менеджмента | Маркетинг | https://nnov.hse.ru/ma/marketing/
# Высшая школа бизнеса | Маркетинг - менеджмент | https://www.hse.ru/ma/markman/
# Высшая школа бизнеса | Маркетинг: цифровые технологии и маркетинговые коммуникации | https://www.hse.ru/ma/mdt/
# Институт торговой политики | Международная торговая политика | https://www.hse.ru/ma/wtp/
# Факультет мировой экономики и мировой политики | Международный бизнес | https://www.hse.ru/ma/inbusiness/
# Санкт-Петербургская школа экономики и менеджмента | Международный бизнес /Master in International Business | https://spb.hse.ru/ma/interbusiness/
# Высшая школа бизнеса | Международный менеджмент /  Master in International Management | https://www.hse.ru/ma/mim/
# Высшая школа юриспруденции и администрирования | Международный спортивный менеджмент и маркетинг | https://www.hse.ru/ma/insport/
# Санкт-Петербургская школа экономики и менеджмента | Менеджмент в индустрии впечатлений | https://spb.hse.ru/ma/expman/
# Высшая школа бизнеса | Менеджмент в ритейле | https://www.hse.ru/ma/retail/
# Санкт-Петербургская школа экономики и менеджмента | Менеджмент и аналитика для бизнеса | https://spb.hse.ru/ma/analytics/
# Факультет менеджмента | Менеджмент качества и бережливого производства | https://nnov.hse.ru/ma/mq/
# Факультет мировой экономики и мировой политики | Мировая экономика | https://www.hse.ru/ma/we/
# Институт демографии имени А.Г. Вишневского | Население и развитие / Population and development | https://www.hse.ru/ma/pd/
# Санкт-Петербургская школа экономики и менеджмента | Прикладная экономика и математические методы | https://spb.hse.ru/ma/aemm/
# Высшая школа бизнеса | Производственные системы и операционная эффективность | https://www.hse.ru/ma/efficiency/
# Факультет экономических наук | Статистический анализ в экономике | https://www.hse.ru/ma/statanalys/
# Факультет экономических наук | Статистическое моделирование и актуарные расчеты | https://www.hse.ru/ma/actuar/
# Высшая школа бизнеса | Стратегический менеджмент и консалтинг | https://www.hse.ru/ma/osm/
# Санкт-Петербургская школа экономики и менеджмента | Стратегическое управление логистикой | https://spb.hse.ru/ma/log/
# Высшая школа бизнеса | Стратегическое управление логистикой и цепями поставок в цифровой экономике | https://www.hse.ru/ma/smol/
# Факультет экономических наук | Стратегическое управление финансами фирмы | https://www.hse.ru/ma/companyfin/
# Факультет менеджмента | Управление бизнесом в глобальных условиях | https://nnov.hse.ru/ma/global/
# Институт образования | Управление в высшем образовании | https://www.hse.ru/ma/mannedu/
# Институт статистических исследований и экономики знаний | Управление в сфере науки, технологий и инноваций | https://www.hse.ru/ma/sti/
# Высшая школа бизнеса | Управление инвестиционными проектами | https://www.hse.ru/ma/ipm/
# Факультет социальных наук | Управление и экономика здравоохранения | https://www.hse.ru/ma/health/
# Институт образования | Управление образованием | https://www.hse.ru/ma/eduman/
# Санкт-Петербургская школа социальных наук и востоковедения | Управление образованием | https://spb.hse.ru/ma/eduman/
# Факультет менеджмента | Управление образованием | https://nnov.hse.ru/ma/eduman/
# Факультет экономики, менеджмента и бизнес-информатики | Управление проектами: проектный анализ, инвестиции, технологии реализации | https://perm.hse.ru/ma/pm/
# Факультет менеджмента | Управление развитием компании и бизнес-аналитика | https://nnov.hse.ru/ma/man/
# Высшая школа бизнеса | Управление цифровым продуктом | https://www.hse.ru/ma/digitalpm/
# Международный институт экономики и финансов | Финансовая экономика | https://www.hse.ru/ma/financial/
# Факультет экономических наук | Финансовые рынки и финансовые институты | https://www.hse.ru/ma/finmarket/
# Факультет экономики, менеджмента и бизнес-информатики | Финансовые стратегии и аналитика | https://perm.hse.ru/ma/fs/
# Банковский институт | Финансовый аналитик | https://www.hse.ru/ma/fin/
# Факультет экономических наук | Финансовый инжиниринг | https://www.hse.ru/ma/fineng/
# Банковский институт | Финансы | https://www.hse.ru/ma/finance/
# Санкт-Петербургская школа экономики и менеджмента | Финансы | https://spb.hse.ru/ma/finance/
# Факультет экономики НИУ ВШЭ | Финансы | https://nnov.hse.ru/ma/finance/
# Институт образования | Цифровая трансформация образования | https://www.hse.ru/ma/dt/
# Факультет экономики НИУ ВШЭ | Экономика | https://nnov.hse.ru/ma/economics/
# Высшая школа бизнеса | Экономика впечатлений: менеджмент в индустрии гостеприимства и туризме | https://www.hse.ru/ma/tourism/
# Факультет экономики, менеджмента и бизнес-информатики | Экономика впечатлений: музейный, событийный, туристический менеджмент | https://perm.hse.ru/ma/ee/
# Факультет экономических наук | Экономика и экономическая политика | https://www.hse.ru/ma/economicpolicy/
# Факультет экономических наук | Экономический анализ | https://www.hse.ru/ma/economicanalysis/
# Высшая школа бизнеса | Электронный бизнес и цифровые инновации | https://www.hse.ru/ma/elb/
# Московский институт электроники и математики им. А.Н. Тихонова | Интернет вещей и киберфизические системы | https://www.hse.ru/ma/internet/
# Московский институт электроники и математики им. А.Н. Тихонова | Наноэлектроника и квантовые технологии | https://www.hse.ru/ma/nanoelectronics/
# Факультет права | Адвокат по гражданским и уголовным делам | https://www.hse.ru/ma/lawyer/
# Юридический факультет | Гражданское и коммерческое право | https://spb.hse.ru/ma/civilcom/
# Факультет права | История, теория и философия права | https://www.hse.ru/ma/histlaw/
# Факультет права | Комплаенс и профилактика правовых рисков в корпоративном, государственном и некоммерческом секторе | https://www.hse.ru/ma/compliance/
# Факультет права | Корпоративный юрист | https://www.hse.ru/ma/corporate/
# Высшая школа юриспруденции и администрирования | Международное и национальное спортивное право | https://www.hse.ru/ma/sportslaw/
# Факультет права | Международное частное право и международный коммерческий арбитраж | https://www.hse.ru/ma/privlaw/
# Высшая школа юриспруденции и администрирования | Международный корпоративный комплаенс и этика бизнеса | https://www.hse.ru/ma/intercomp/
# Факультет права | Правовое обеспечение и защита бизнеса | https://nnov.hse.ru/ma/ls/
# Социально-гуманитарный факультет | Правовое обеспечение предпринимательской деятельности | https://perm.hse.ru/ma/ls/
# Факультет права | Правовое регулирование в фармацевтике и биотехнологиях | https://www.hse.ru/ma/legalpharma/
# Юридический факультет | Право и государственное управление | https://spb.hse.ru/ma/lpa/
# Юридический факультет | Право интеллектуальной собственности в цифровую эпоху | https://spb.hse.ru/ma/iplaw/
# Факультет права | Право международной торговли, финансов и экономической интеграции/Law of International Trade, Finance and Economic Integration | https://www.hse.ru/ma/intrade/
# Факультет права | Публичное право | https://www.hse.ru/ma/publiclaw/
# Факультет права | Финансовое, налоговое и таможенное право | https://www.hse.ru/ma/fnt/
# Высшая школа юриспруденции и администрирования | Церковь, общество и государство. Правовое регулирование деятельности религиозных объединений | https://www.hse.ru/ma/canon/
# Факультет права | Цифровое право | https://www.hse.ru/ma/dlaw/
# Факультет права | Частное право | https://www.hse.ru/ma/plaw/
# Факультет права | Юрист в правосудии и правоохранительной деятельности | https://www.hse.ru/ma/llle/
# Высшая школа юриспруденции и администрирования | Юрист мирового финансового рынка | https://www.hse.ru/ma/finlaw/
# Школа иностранных языков | Иностранные языки и межкультурная коммуникация | https://www.hse.ru/ma/lc/
# Факультет гуманитарных наук | Компьютерная лингвистика | https://www.hse.ru/ma/ling/
# Факультет гуманитарных наук | Лингвистическая теория и описание языка | https://www.hse.ru/ma/tling/
# Факультет гуманитарных наук | Литературное мастерство | https://www.hse.ru/ma/litmaster/
# Факультет гуманитарных наук | Медиатекст и цифровые коммуникации | https://nnov.hse.ru/ma/litmedia/
# Факультет гуманитарных наук | Прикладная лингвистика и текстовая аналитика / Applied Linguistics and Text Analytics | https://nnov.hse.ru/ma/appling/
# Санкт-Петербургская школа гуманитарных наук и искусств | Русская литература в кросс-культурной и интермедиальной перспективах | https://spb.hse.ru/ma/rlcip/
# Факультет гуманитарных наук | Русская литература и компаративистика | https://www.hse.ru/ma/literature/
# Факультет гуманитарных наук | Русский язык как иностранный во взаимодействии языков и культур | https://www.hse.ru/ma/foreign/
# Факультет гуманитарных наук | Современная филология в преподавании литературы в школе | https://www.hse.ru/ma/langart/
# Школа лингвистики | Цифровые методы в гуманитарных науках | https://www.hse.ru/ma/dh/
# Факультет гуманитарных наук | Языковая политика в условиях этнокультурного разнообразия | https://www.hse.ru/ma/langpolicy/
# Санкт-Петербургская школа гуманитарных наук и искусств | Языковые технологии в бизнесе и образовании | https://spb.hse.ru/ma/language/

# %% [markdown]
# Видим, что несмотря на то, что в изначальном url-е было явно указано ```...msk/bachelor```, в html-коде имеются программы не только из Москвы и не только бакалаврские. Поймем, как отфильтровать лишнее. Для этого взглянем на ```div```-ы, отвечающие одной ОП:

# %%
def program_info(index):
    program = programs[index]
    print(program('div', 'edu-programm__unit')[0]('span')[0].text)
    print(program.prettify())


program_info(10)
program_info(-1)
# Out:
# Пермь
# <div class="b-row edu-programm__item" data-filters='[122472763,51999666,91519646,"54.00.00 Изобразительное искусство и прикладные виды искусств","ru","p","pf","full","online","Дизайн","crcmp","rl","literature"]' style="display: none;">
#  <div class="b-row__item b-row__item--6 b-row__item--t12">
#   <a class="link" href="https://perm.hse.ru/ba/design/">
#    Дизайн
#   </a>
#   <div class="edu-programm__unit">
#    <span class="edu-programm__city with-icon with-icon_flag-perm">
#     Пермь
#    </span>
#    <span class="grey">
#     Социально-гуманитарный факультет
#    </span>
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#   <div class="edu-programm__data u-accent">
#    4 года
#   </div>
#   <div class="edu-programm__edu_offline">
#    Очная
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#   <div class="b-row__item--place">
#    <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#     50/5
#    </div>
#    <div class="tooltip">
#     <div class="with-indent1">
#      50 платных
#     </div>
#     <div class="with-indent1">
#      5 платных мест для иностранцев
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#   <div class="edu-programm__data u-accent">
#    320 000 руб. в год
#   </div>
#  </div>
# </div>
#
# Санкт-Петербург
# <div class="b-row edu-programm__item" data-filters='[53352697,51999665,222569607,"45.00.00 Языкознание и литературоведение","ruen","p","pf","full","Языковые технологии в бизнесе и образовании"]' style="display: none;">
#  <div class="b-row__item b-row__item--6 b-row__item--t12">
#   <a class="link" href="https://spb.hse.ru/ma/language/">
#    Языковые технологии в бизнесе и образовании
#   </a>
#   <div class="edu-programm__unit">
#    <span class="edu-programm__city with-icon with-icon_flag-spb">
#     Санкт-Петербург
#    </span>
#    <span class="grey">
#     Санкт-Петербургская школа гуманитарных наук и искусств
#    </span>
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--period">
#   <div class="edu-programm__data u-accent">
#    2 года
#   </div>
#   <div class="edu-programm__edu_offline">
#    Очная
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--4 b-row__item--t8 b-row__item--places">
#   <div class="b-row__item--place">
#    <div class="edu-programm__data u-accent edu-program-places" style="display:none;">
#     13/2
#    </div>
#    <div class="tooltip">
#     <div class="with-indent1">
#      13 платных
#     </div>
#     <div class="with-indent1">
#      2 платных места для иностранцев
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="b-row__item b-row__item--2 b-row__item--t4 b-row__item--cost" style="display: none;">
#   <div class="edu-programm__data u-accent">
#    270 000 руб. в год
#   </div>
#  </div>
# </div>

# %% [markdown]
# Отфильтровать по городу просто: соответствующий ```span``` имеется в коде выше. Но как понять из него, является ОП бакалаврской или магистерской? Кажется, самый простой спрособ это сделать &mdash; посмотреть на ссылку на страницу ОП: если она содержит ```ba```, значит это бакалавриат.

# %% [markdown]
# В процессе первичной обработки обнаружилась проблема. Большинство страниц ОП имеют ссылки в домене просто ```hse.ru```, и с ними всё в порядке: формат ссылок один и тот же и, самое главное, страницы с рейтингами имеют одинаковый вид. Но для некоторых программ и формат ссылок, и страницы с рейтинами выглядят по-другому. Посмотрим на них:

# %%
for program in programs:
    town, faculty = [program('div', 'edu-programm__unit')[0]('span')[i].text for i in [0, 1]]
    url = program.a['href']
    name = program.a.text
    if town == 'Москва' and url.split('/')[2] != 'www.hse.ru':
        print(faculty, name, url, sep=' | ')
# Out:
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Дизайн | https://design.hse.ru/ba/program/design
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Мода | https://design.hse.ru/ba/program/fashion
# Факультет коммуникаций, медиа и дизайна | Современное искусство | https://art.hse.ru/ba
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Дизайн | http://design.hse.ru/mag-design
# Факультет коммуникаций, медиа и дизайна | Дизайн интерьера | https://design.hse.ru/ma/program/interior
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Коммуникационный и цифровой дизайн | http://design.hse.ru/mag-comm
# Факультет коммуникаций, медиа и дизайна, Школа дизайна | Мода | http://design.hse.ru/mag-fashion
# Школа дизайна | Практики современного искусства | http://art.hse.ru/ma
# Школа дизайна | Современный дизайн в преподавании изобразительного искусства и технологии в школе | http://design.hse.ru/pages/184

# %% [markdown]
# Как видно, из бакалаврских программ "нерегулярных" всего 3. Их страницы лежат в доменах ```design.hse.ru``` и ```art.hse.ru```. Не будем с ними заморачиваться и просто отфильтруем :)

# %%
def sanitize_str(s):
    return s.strip().replace('\xa0', ' ')


faculties = {}
for program in programs:
    town, faculty = [sanitize_str(program('div', 'edu-programm__unit')[0]('span')[i].text) for i in [0, 1]]
    url = program.a['href'].split('/')
    if (town == 'Москва') and ('ba' in url) and (url[2] == 'www.hse.ru'):
        name = sanitize_str(program.a.text)
        code = url[-2]
        if faculty not in faculties:   
            faculties[faculty] = set()
        faculties[faculty].add((name, code))
faculties
# Out:
# {'Факультет городского и регионального развития': {('Городское планирование',
#    'up')},
#  'Факультет биологии и биотехнологии': {('Клеточная и молекулярная биотехнология',
#    'cmb')},
#  'Институт классического Востока и античности': {('Античность', 'antiq'),
#   ('Арабистика: язык, словесность, культура', 'arabic'),
#   ('Христианский Восток', 'christian'),
#   ('Язык, словесность и культура Китая', 'chinese')},
#  'Факультет мировой экономики и мировой политики': {('Востоковедение',
#    'oriental'),
#   ('Международные отношения', 'ia'),
#   ('Мировая экономика', 'we'),
#   ('Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям',
#    'ir'),
#   ('Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»',
#    'epa')},
#  'Московский институт электроники и математики им. А.Н. Тихонова': {('Информатика и вычислительная техника',
#    'isct'),
#   ('Компьютерная безопасность', 'cosec'),
#   ('Прикладная математика', 'am')},
#  'Факультет компьютерных наук': {('Компьютерные науки и анализ данных',
#    'compds'),
#   ('Прикладная математика и информатика', 'ami'),
#   ('Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»',
#    'data'),
#   ('Программная инженерия', 'se')},
#  'Московский институт электроники и математики им. А.Н. Тихонова, Департамент электронной инженерии': {('Инфокоммуникационные технологии и системы связи',
#    'it'),
#   ('Информационная безопасность', 'is')},
#  'Факультет гуманитарных наук': {('История', 'hist'),
#   ('История искусств', 'histart'),
#   ('Культурология', 'cultural'),
#   ('Филология', 'philology'),
#   ('Философия', 'phil'),
#   ('Фундаментальная и компьютерная лингвистика', 'ling')},
#  'Факультет математики': {('Математика', 'math'),
#   ('Совместный бакалавриат НИУ ВШЭ и ЦПМ', 'cpm')},
#  'Факультет географии и геоинформационных технологий': {('География глобальных изменений и геоинформационные технологии',
#    'geography')},
#  'Факультет социальных наук': {('Государственное и муниципальное управление',
#    'gmu'),
#   ('Политология', 'political'),
#   ('Психология', 'psy'),
#   ('Социология', 'soc')},
#  'Факультет коммуникаций, медиа и дизайна': {('Журналистика', 'journ'),
#   ('Медиакоммуникации', 'media'),
#   ('Реклама и связи с общественностью', 'ad')},
#  'Факультет физики': {('Физика', 'physics')},
#  'Факультет химии': {('Химия', 'chem')},
#  'Высшая школа бизнеса': {('Бизнес-информатика', 'bi'),
#   ('Логистика и управление цепями поставок', 'logistics'),
#   ('Маркетинг и рыночная аналитика', 'marketing'),
#   ('Управление бизнесом', 'bba'),
#   ('Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)',
#    'digital')},
#  'Международный институт экономики и финансов': {('Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета',
#    'icef')},
#  'Факультет экономических наук': {('Совместная программа по экономике НИУ ВШЭ и РЭШ',
#    'nes'),
#   ('Экономика', 'economics'),
#   ('Экономика и статистика', 'stat')},
#  'Факультет права': {('Юриспруденция', 'law'),
#   ('Юриспруденция: частное право', 'privlaw')},
#  'Школа иностранных языков': {('Иностранные языки и межкультурная коммуникация',
#    'lang')}}

# %% [markdown]
# Итак, мы распарсили и отфильтровали факультеты и реализуемые на них ОП. Кроме того, для каждой ОП мы получили ее "код", используемый в ссылке на ее страницу, где, в свою очередь, хранятся нужные нам рейтинги. Например, для ПМИ страница с рейтингами находится по адресу https://www.hse.ru/ba/ami/ratings. Для остальных ("регулярных") ОП аналогично.
#
# Приступим к парсингу страниц с рейтингами (на примере ПМИ):

# %%
query_facutly = 'Факультет компьютерных наук'
query_program = 'Прикладная математика и информатика'
query_course = 2
query_rating = 'Кумулятивный рейтинг по итогам 1-2 модулей 2020/2021 уч.г.'

code = [prog[1] for prog in faculties[query_facutly] if prog[0] == query_program][0]
rating_url = f'https://www.hse.ru/ba/{code}/ratings'
response = requests.get(rating_url)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- (c) Art. Lebedev Studio | http://www.artlebedev.com/ -->
# <html lang="ru" xmlns:perl="urn:perl">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="#1658DA" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/f/src/global/i/favicon/favicon_ios_180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/f/src/global/i/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/f/src/global/i/favicon/favicon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#242f63" href="/f/src/global/i/favicon/favicon.svg" rel="mask-icon"/>
#   <link href="/f/src/manifest/manifest_ru.json" rel="manifest"/>
#   <meta content="/f/src/global/i/favicon/browserconfig.xml" name="msapplication-config"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->
#   <link href="/f/src/global/css/main.css?v2" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/vision.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/sitemap.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/fotorama.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/owl.carousel2.min.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/edu_card/edu_card.css?v3" media="all" rel="stylesheet"/>
#   <link href="/f/src/promo/gallery-promo.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/postupi/postupi.css" media="all" rel="stylesheet"/>
#   <script src="//www.hse.ru/f/src/global/js/cache/jquery-1.12.4.min/jquery-ui/jquery.ui.touch-punch.min/hse.utils/errtrack/main/modernizr/popup/switcher/tag/fixes/email-obfuscator/jquery.cookie/vision/jquery.rwdImageMaps.min/sitemap.ajax/fotorama/slider/jquery.menu-aim/menu-aim-init/jquery.carouFredSel-6.2.1-packed/hs/mag/init-social-carousel/init-media-carousel/owl.carousel2.min/edu-card/edu_mobile.js">
#   </script>
#   <script src="/f/src/global/js/gibs.js">
#   </script>
#   <script src="/f/src/student-ratings/student-ratings.js">
#   </script>
#   <link href="/f/src/student-ratings/student-ratings.css" media="all" rel="stylesheet"/>
#   <script async="async" src="https://www.hse.ru/f/src/global/js/job.js">
#   </script>
#   <title>
#    Образовательная программа «Прикладная математика и информатика» — Национальный исследовательский университет «Высшая школа экономики»
#   </title>
#   <script src="/f/gtm/ip">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-P6DCQX');
#   </script>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" property="og:title"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" name="mrc__share_title"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" itemprop="name"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" name="twitter:title"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" property="og:description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" name="mrc__share_description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" itemprop="description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»)." name="twitter:description"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" property="og:image"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" itemprop="image"/>
#   <link content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" rel="image_src"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" name="twitter:image"/>
#   <meta content="https://www.hse.ru/ba/ami/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.hse.ru/ba/ami/" name="twitter:url"/>
#   <link href="/f/src/projects/edu_card/mobile.css" rel="stylesheet"/>
#   <script>
#    $(function() {
# 				if ($('.from-group').length > 0 ) {
# 					$('.from-group').carouFredSel({
# 						auto: false,
# 						width: '99%',
# 						height: 'auto',
# 						scroll: 2,
# 						align: 'center',
# 						items: {
# 				 			width: '200',
# 							visible: {
# 								min: 1,
# 								max: 6
# 							}
# 						},
# 						next: {
# 							button: function() { return $(this).parent().siblings(".b-group-next")},
# 							key: 'right'
# 						},
# 						prev: {
# 							button: function() { return $(this).parent().siblings(".b-group-prev")},
# 							key: 'left'
# 						}
# 					});
# 				}
# 			});
#   </script>
#  </head>
#  <body data-lang="ru" data-unit="122722317">
#   <div class="page">
#    <!--noindex-->
#    <div class="browser_outdate" style="display:none;">
#     В старых версиях браузеров сайт может отображаться некорректно. Для оптимальной работы с сайтом рекомендуем воспользоваться современным браузером.
#    </div>
#    <div class="gdpr_bar" style="display:none;">
#     <div class="gdpr_bar__inner">
#      <noindex>
#       <p class="first_child last_child">
#        Мы используем файлы cookies для улучшения работы сайта НИУ ВШЭ и большего удобства его использования. Более подробную информацию об использовании файлов cookies можно найти
#        <a class="link" href="https://www.hse.ru/cookie.html" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        , наши правила обработки персональных данных –
#        <a class="link" href="https://www.hse.ru/data_protection_regulation" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        . Продолжая пользоваться сайтом, вы подтверждаете, что были проинформированы об использовании файлов cookies сайтом НИУ ВШЭ и согласны с нашими правилами обработки персональных данных. Вы можете отключить файлы cookies в настройках Вашего браузера.
#       </p>
#      </noindex>
#      <span class="gdpr_bar__close">
#       ✖
#      </span>
#     </div>
#    </div>
#    <!--/noindex-->
#    <div class="sv-control">
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-size">
#       <li class="sv-control__item sv-control__item--s_normal active" data-type="size" data-value="normal">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_medium" data-type="size" data-value="medium">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_large" data-type="size" data-value="large">
#        A
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-spacing">
#       <li class="active sv-control__item sv-control__item--ls_normal" data-type="spacing" data-value="normal">
#        АБВ
#       </li>
#       <li class="sv-control__item sv-control__item--ls_medium" data-type="spacing" data-value="medium">
#        АБВ
#       </li>
#       <li class="sv-control__item sv-control__item--ls_large" data-type="spacing" data-value="large">
#        АБВ
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-contrast">
#       <li class="sv-control__item sv-control__item---color1 active" data-type="contrast" data-value="normal">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color2" data-type="contrast" data-value="invert">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color3" data-type="contrast" data-value="blue">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color4" data-type="contrast" data-value="beige">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color5" data-type="contrast" data-value="brown">
#        А
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-image">
#       <li class="sv-control__item sv-control__item--image_on active" data-type="image" data-value="on">
#        <li class="sv-control__item sv-control__item--image_off" data-type="image" data-value="off">
#        </li>
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <div class="sv-off js-sv-off">
#       Обычная версия сайта
#      </div>
#     </div>
#    </div>
#    <div class="fa-sidebar">
#     <div class="fa-sidebar__top fa-sidebar__top--overlay fa-sidebar__top--secondary" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#      <div class="fa-sidebar__controls is-mobile">
#       <ul class="control_lang2">
#        <li class="control_lang2_item first_child activated">
#         <span class="link link_no-visited link_no-underline">
#          RU
#         </span>
#        </li>
#        <li class="control_lang2_item last_child">
#         <a class="link link_no-visited link_no-underline" href="https://www.hse.ru/en/ba/ami/ratings">
#          EN
#         </a>
#        </li>
#       </ul>
#       <a class="control control_user control_white" href="//www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#        <ins>
#         <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#          <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#          </path>
#         </svg>
#        </ins>
#       </a>
#       <span class="control control_search control_white js-search_mobile_control">
#        <ins>
#         <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#          <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#          </path>
#         </svg>
#        </ins>
#       </span>
#       <span class="control is-mobile control_menu control_menu--close js-control_menu_close" onclick="void(0)" style="cursor:pointer;">
#        <ins>
#        </ins>
#       </span>
#      </div>
#      <div class="js-search_mobile_popup not_display is-mobile">
#       <div class="search-form">
#        <form action="/search/search.html">
#         <div class="search-form__button">
#          <button class="button button--merged button_grey">
#           Найти
#          </button>
#         </div>
#         <div class="search-form__input">
#          <input class="input fa-search_input input100 input_mr" name="text" placeholder="Поиск по сайту" type="text"/>
#          <input name="simple" type="hidden" value="1"/>
#         </div>
#        </form>
#       </div>
#       <div class="popup__block">
#        <a class="link link_white no-visited" href="//www.hse.ru/search/search.html?simple=0">
#         Расширенный поиск по сайту
#        </a>
#       </div>
#      </div>
#      <div class="fa-sidebar__title_inner">
#       <a class="link_white link_no-underline no-visited" href="https://www.hse.ru/ba/ami">
#        Бакалаврская программа «Прикладная математика и информатика»
#       </a>
#      </div>
#     </div>
#     <ul class="fa-sidemenu fa-sidemenu--primary">
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         О программе
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/about">
#          О программе
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/pilot">
#          Пилотный поток
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/features">
#          Особенности программы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/faculty12">
#          Лекторы 1-2 курсов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/projects">
#          Проектная и научная работа
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/spec">
#          О специализациях
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://cs.hse.ru/electives" target="_blank">
#          Факультативы ФКН
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/partners">
#          Партнеры
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/success">
#          Достижения студентов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://cs.hse.ru/alumni/">
#          Выпускники
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Абитуриентам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 selected fa-sidemenu__link" href="https://www.hse.ru/ba/ami/admission/">
#          Паспорт программы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/tracks">
#          Траектории поступления
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/applicantvoc">
#          Карманный словарь абитуриента
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/requirements">
#          Подготовка
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/1scholarships">
#          Стипендии для поступивших
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/test">
#          Тестирование по математике и программированию
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/career">
#          Будущая профессия
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://fdp.hse.ru/ischool/">
#          Онлайн-подготовка
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Студентам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 selected fa-sidemenu__link" href="https://www.hse.ru/ba/ami/students/">
#          Доска объявлений
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="http://electives.hse.ru/">
#          Выбор траектории обучения
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://electives.hse.ru/" target="_blank">
#               Общеуниверситетские курсы
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/org/hse/elective_courses/MN_OI" target="_blank">
#               Майноры
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/21-22-767b7191bb8c4a4c96b0c33fa3b27ad8" rel="nofollow" target="_blank">
#          Курсы по выбору 2021-22
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/2021-af3df9c18e664fc08cacc4ab1df51396" rel="nofollow" target="_blank">
#          Специализации
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/theses">
#          Курсовые и ВКР
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/theses21">
#               Курсовые работы
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/vkr">
#               Выпускные квалификационные работы
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/internships">
#          Практика
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/practiceami2">
#               Учебная практика (1 курс)
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/internships">
#               Производственная практика (3 курс)
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/diplomapractice">
#               Преддипломная практика
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent">
#          Проекты
#         </span>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/projectwork">
#               Программный проект 2 курса
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/Project-Proposal-0aa7fa0dd99a4a6abbe6ed19e65b7c03" rel="nofollow">
#          Project Proposal
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/assessment">
#          Итоговая аттестация
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/diplomas">
#          Каталог ВКР
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent">
#          Расписание
#         </span>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/scheduletable">
#               Расписание онлайн
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/examschedule">
#               Расписание экзаменов
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/resit">
#               Расписание пересдач
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/grafik">
#               График учебного процесса
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://cs.hse.ru/electives" target="_blank">
#          Факультативы ФКН
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/tests">
#          Первокурсникам
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/tests">
#               Тестирование первокурсников
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/1year" target="_blank">
#               To Do List первокурсника ПМИ
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/orientationweek">
#               БЖД
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/transfer">
#          Перевод и восстановление на программу
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/moocs">
#          Рекомендованные онлайн-курсы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/mobility">
#          Студенческая мобильность
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link selected" href="https://www.hse.ru/ba/ami/ratings">
#          Рейтинги
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/hselang/">
#          Дополнительные иностранные языки
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/safety" target="_blank">
#          Мониторинг здоровья студентов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link">
#         </span>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/is">
#          Иностранные студенты
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Выпускникам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://cs.hse.ru/alumni/">
#          Общая информация
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://family.hse.ru/">
#          Вышка.Family
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://career.hse.ru/">
#          Центр развития карьеры
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/">
#          Центр по работе с выпускниками
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/propusk_hse">
#          Пропуск выпускника
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/ambassadors">
#          HSE Alumni Ambassadors
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/fellowship/">
#          HSE Alumni Academic Fellowship
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section fa-sidemenu__section--add js-sidemenu__section--add">
#      </li>
#     </ul>
#    </div>
#    <div class="header" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#     <div class="crop">
#      <div class="header-top header-top--stoped links-white" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#       <div class="left">
#        <span class="control control_sitemap">
#         <span class="control_sitemap__line">
#         </span>
#        </span>
#        <a class="control control_home_white" href="//www.hse.ru/">
#         <ins>
#          <svg height="26" viewbox="0 0 18 26" width="18" xmlns="http://www.w3.org/2000/svg">
#           <path d="M6.66 0l.134.002h1.336c2.639 0 3.745.464 4.994 1.428 1.819 1.424 2.105 3.492 2.105 4.525 0 1.283-.393 2.638-1.356 3.742-.714.856-1.955 2.097-4.388 2.388-1.663.2-2.891.127-3.506.061v-1.306c.273.038.676.074 1.222.074 1.656 0 2.829-.827 3.543-1.719.81-.983.98-1.909 1.015-2.737h-4.555v-1.282h4.515c-.116-.866-.448-1.528-.985-2.179-1.035-1.283-2.499-1.497-3.462-1.497l-6.505-.002-.768-1.498h6.66zm-6.317 26l.804-1.564v-21.844h3.55v21.82h2.508v-8.523h3.276v8.514h2.838v-3.878c0-2.351-.122-5.622-2.77-7.311l1.542-.566c3.194 1.186 4.791 4.283 4.791 8.362v3.428l.804 1.562h-17.344z" fill="#1658DA">
#           </path>
#          </svg>
#         </ins>
#        </a>
#       </div>
#       <div class="right">
#        <div class="header__controls">
#         <ul class="control_lang2">
#          <li class="control_lang2_item first_child activated">
#           <span class="link link_no-visited link_no-underline">
#            RU
#           </span>
#          </li>
#          <li class="control_lang2_item last_child">
#           <a class="link link_no-visited link_no-underline" href="https://www.hse.ru/en/ba/ami/ratings">
#            EN
#           </a>
#          </li>
#         </ul>
#         <span class="control control_vision control_white" title="Версия для слабовидящих">
#          <svg height="12" viewbox="0 0 21 12" width="21" xmlns="http://www.w3.org/2000/svg">
#           <path d="M10.5 0c3.438 0 6.937 2.016 10.5 6.047-.844.844-1.383 1.375-1.617 1.594-.234.219-.805.703-1.711 1.453-.906.75-1.641 1.266-2.203 1.547-.563.281-1.305.578-2.227.891-.922.313-1.836.469-2.742.469-1.125 0-2.156-.141-3.094-.422-.938-.281-1.875-.766-2.813-1.453-.938-.688-1.672-1.273-2.203-1.758-.531-.484-1.328-1.273-2.391-2.367 2.031-2.031 3.836-3.539 5.414-4.523 1.578-.984 3.273-1.477 5.086-1.477zm0 10.266c1.156 0 2.148-.422 2.977-1.266.828-.844 1.242-1.844 1.242-3s-.414-2.156-1.242-3c-.828-.844-1.82-1.266-2.977-1.266-1.156 0-2.148.422-2.977 1.266-.828.844-1.242 1.844-1.242 3s.414 2.156 1.242 3c.828.844 1.82 1.266 2.977 1.266zm0-5.766c0 .438.141.797.422 1.078s.641.422 1.078.422c.313 0 .625-.109.938-.328v.328c0 .688-.234 1.273-.703 1.758-.469.484-1.047.727-1.734.727-.688 0-1.266-.242-1.734-.727-.469-.484-.703-1.07-.703-1.758s.234-1.273.703-1.758c.469-.484 1.047-.727 1.734-.727h.375c-.25.313-.375.641-.375.984z" fill="#1658DA">
#           </path>
#          </svg>
#         </span>
#         <a class="control control_user control_white" href="//www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#          <ins>
#           <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#            <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#         </a>
#         <span class="control control_search control_white" title="Поиск">
#          <ins class="popup_opener">
#           <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#            <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#          <div class="popup popup_search not_display">
#           <div class="popup__inner">
#            <div class="search-form">
#             <form action="https://www.hse.ru/ba/ami/search/search.html">
#              <div class="search-form__button">
#               <button class="button button_grey">
#                Найти
#               </button>
#              </div>
#              <div class="search-form__input">
#               <input class="input input100 input_mr" name="text" placeholder="Поиск по сайту" type="text"/>
#               <input name="simple" type="hidden" value="1"/>
#               <input name="searchid" type="hidden" value="2284688"/>
#              </div>
#             </form>
#            </div>
#            <div class="popup__block popup__block_indent">
#             <a class="link link_dark no-visited" href="//www.hse.ru/search/search.html?simple=0&amp;searchid=2284688">
#              Расширенный поиск по сайту
#             </a>
#             <span class="b-adv-search">
#             </span>
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="control is-mobile control_menu js-control_menu_open" onclick="void(0)" style="cursor:pointer;">
#          <ins>
#          </ins>
#          <span class="control__text">
#           Меню
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="header_body">
#        <div class="header_breadcrumb">
#         <div class="header_breadcrumb__inner is-mobile no_crumb_arrow">
#          <a class="link_white no-visited link" href="https://www.hse.ru">
#           Высшая школа экономики
#          </a>
#         </div>
#         <div class="header_breadcrumb__inner is-desktop no_crumb_arrow">
#          <ul class="header_breadcrumb__list">
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="//www.hse.ru">
#             <span>
#              Национальный исследовательский университет «Высшая школа экономики»
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="https://www.hse.ru/education/bachelor/">
#             <span>
#              Образовательные программы бакалавриата
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="https://cs.hse.ru/">
#             <span>
#              Факультет компьютерных наук
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <span>
#             <span class="breadcrumb_current">
#              Образовательная программа «Прикладная математика и информатика»
#             </span>
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header-board row">
#       <div class="extra-left">
#        <div class="header-content">
#         <h2 class="h1">
#          <a class="link_white link_no-underline no-visited" href="https://www.hse.ru/ba/ami">
#           Бакалаврская программа «Прикладная математика и информатика»
#          </a>
#         </h2>
#         <div class="menu edu-menu">
#          <ul class="navigation navigation_horizontal navigation_newl">
#           <li class="single">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/">
#             <span class="link">
#              <span class="icon icon-home">
#               <svg height="15" viewbox="0 0 16 15" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path d="M6.122 14.692h-3.75V7.346H0L7.958 0l7.959 7.346h-2.373v7.346h-3.75V9.795H6.123z" fill="#FFF" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/about/">
#             <span class="link">
#              О программе
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select0">
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/about">
#               <span class="link">
#                О программе
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/pilot">
#               <span class="link">
#                Пилотный поток
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/features">
#               <span class="link">
#                Особенности программы
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/faculty12">
#               <span class="link">
#                Лекторы 1-2 курсов
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/projects">
#               <span class="link">
#                Проектная и научная работа
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/spec">
#               <span class="link">
#                О специализациях
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://cs.hse.ru/electives" target="_blank">
#               <span class="link">
#                Факультативы ФКН
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/partners">
#               <span class="link">
#                Партнеры
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/success">
#               <span class="link">
#                Достижения студентов
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://cs.hse.ru/alumni/">
#               <span class="link">
#                Выпускники
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/admission/">
#             <span class="link">
#              Абитуриентам
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select0">
#             <li>
#              <a class="link" href="https://www.hse.ru/ba/ami/admission/">
#               Паспорт программы
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/tracks">
#               <span class="link">
#                Траектории поступления
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/applicantvoc">
#               <span class="link">
#                Карманный словарь абитуриента
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/requirements">
#               <span class="link">
#                Подготовка
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/1scholarships">
#               <span class="link">
#                Стипендии для поступивших
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/test">
#               <span class="link">
#                Тестирование по математике и программированию
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/career">
#               <span class="link">
#                Будущая профессия
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://fdp.hse.ru/ischool/">
#               <span class="link">
#                Онлайн-подготовка
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="selected">
#            <a class="link link_no-underline selected" href="https://www.hse.ru/ba/ami/students/">
#             <span class="link">
#              Студентам
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select1">
#             <li>
#              <a class="link" href="https://www.hse.ru/ba/ami/students/">
#               Доска объявлений
#              </a>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="http://electives.hse.ru/">
#               <span class="link pseudo_link sub_link">
#                Выбор траектории обучения
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="http://electives.hse.ru/" target="_blank">
#                 <span class="link">
#                  Общеуниверситетские курсы
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/org/hse/elective_courses/MN_OI" target="_blank">
#                 <span class="link">
#                  Майноры
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.notion.so/21-22-767b7191bb8c4a4c96b0c33fa3b27ad8" rel="nofollow" target="_blank">
#               <span class="link">
#                Курсы по выбору 2021-22
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.notion.so/2021-af3df9c18e664fc08cacc4ab1df51396" rel="nofollow" target="_blank">
#               <span class="link">
#                Специализации
#               </span>
#              </a>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/theses">
#               <span class="link pseudo_link sub_link">
#                Курсовые и ВКР
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/theses21">
#                 <span class="link">
#                  Курсовые работы
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/vkr">
#                 <span class="link">
#                  Выпускные квалификационные работы
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/internships">
#               <span class="link pseudo_link sub_link">
#                Практика
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/practiceami2">
#                 <span class="link">
#                  Учебная практика (1 курс)
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/internships">
#                 <span class="link">
#                  Производственная практика (3 курс)
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/diplomapractice">
#                 <span class="link">
#                  Преддипломная практика
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="">
# ...
#               <td class="p1 special-table__cell special-table__cell--place">
#                320
#               </td>
#               <td class="p2 special-table__cell special-table__cell--grade_mid">
#                0.75
#               </td>
#               <td class="p3 special-table__cell special-table__cell--grade_min">
#                0
#               </td>
#               <td class="p4 special-table__cell special-table__cell--percentil">
#                99.69%
#               </td>
#               <td class="p5 special-table__cell special-table__cell--grade_gpa">
#                0.76
#               </td>
#              </tr>
#             </table>
#             <p>
#              <a class="link" href="https://www.hse.ru/ba/ami/ratings/archive">
#               Рейтинги студентов за предыдущие периоды
#              </a>
#             </p>
#             <p>
#              Расчет и публикация рейтингов студентов осуществляется на основании
#              <a class="link" href="https://www.hse.ru/docs/295301710.html">
#               Положения о рейтинговой системе комплексной оценки знаний студентов образовательных программ бакалавриата, специалитета и магистратуры Национального исследовательского университета «Высшая школа экономики»
#              </a>
#             </p>
#             <p class="last_child">
#              Детализированная информация по оценкам доступна каждому студенту и преподавателям НИУ ВШЭ через систему LMS
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="post post_single3 addthiscode">
#          <div class="post__content">
#           <script async="async" charset="utf-8" src="//yastatic.net/share2/share.js" type="text/javascript">
#           </script>
#           <div class="ya-share2" data-description="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" data-image="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" data-lang="ru" data-limit="6" data-services="facebook,vkontakte,twitter,telegram,whatsapp,viber" data-title="Образовательная программа «Прикладная математика и информатика»" data-url="https://www.hse.ru/ba/ami/">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--banner -->
#     <a class="adv_flyout adv_flyout--banner link_no-underline" href="https://studyabroad.hse.ru/catalogue/" style="top: 45%">
#      <div class="adv_flyout__corner" style=" background-color: #9d2004;">
#      </div>
#      <div class="adv_flyout__content links-white adv_flyout__content--banner" style="background-color: #9d2004">
#       <div class="adv_flyout__content_inner" style="background-image: url(/pubs/share/direct/218771813.jpg);">
#       </div>
#      </div>
#     </a>
#     <style>
#      .adv_flyout {
# 		display: flex;
# 		height: 90px;
# 		visibility: hidden;
# 		margin: 20px 0;
# 	}
# 	.adv_flyout__corner {
# 		display: none;
# 		width: 30px;
# 		height: 90px;
# 		flex: 0 0 30px;
# 		background: center #1658DA no-repeat;
# 		background-size: cover;
# 	}
# 	.adv_flyout__content {
# 		flex: 1 1 auto;
# 		background-color: #1658DA;
# 	}
# 	.adv_flyout__content_inner {
# 		padding: .7em;
# 		background: center no-repeat;
# 		background-size: cover;
# 		background-color: inherit;
# 		color: #fff;
# 		box-sizing: border-box;
# 	}
# 	.adv_flyout--banner  .adv_flyout__content_inner {
# 		height: 90px;
# 	}
# 	.adv_flyout *:first-child {
# 		margin-top: 0;
# 	}
# 	@media (min-width: 768px) {
# 		.adv_flyout {
# 			position: fixed;
# 			z-index: 5;
# 			width: 269px;
# 			right: -239px;
# 			top: 30%;
# 			transition: right .5s ease 0s;
# 			padding: 0;
# 			margin: 0;
# 		}
#
# 		.adv_flyout--minimize.adv_flyout--minimize {
# 			right: -239px;
# 		}
# 		.adv_flyout--full.adv_flyout--full {
# 			right: 0;
# 		}
# 		.adv_flyout__corner {
# 			display: block;
# 			position: absolute;
# 			top: 0;
# 			left: 0;
# 		}
# 		.adv_flyout--full .adv_flyout__corner {
# 			cursor: pointer;
# 		}
# 		.adv_flyout__content {
# 			margin-left: 30px;
# 		}
# 	}
# 	@media (max-width: 767px) {
# 		.adv_flyout {
# 			height: auto;
# 		}
# 	}
#     </style>
#     <script>
#      $(function() {
# function LoadImage() {
# 	var img = new Image();
# 	img.onload = function() {
# 		setTimeout(function(){
# 			//IE
# 			if (!('remove' in Element.prototype)) {
# 				Element.prototype.remove = function() {
# 					if (this.parentNode) {
# 						this.parentNode.removeChild(this);
# 					}
# 				};
# 			}
#
# 			img.remove();
# 			$('.adv_flyout').css('visibility','visible');
# 		}, (parseFloat(3, 10) * 1000));
# 	};
# 	img.src = "/pubs/share/direct/218771813.jpg";
# }
# LoadImage();
#
# var flyoutShownFlag = false;
# var flyoutFocusFlag = false;
# var flyoutHide;
# $('.adv_flyout').hover(function() {
# 	if(!flyoutShownFlag) {
# 		$(this).addClass('adv_flyout--full');
# 		flyoutShownFlag = true;
# 	}
# 	clearTimeout(flyoutHide);
# 	return false
# },function(){
# 	if(!flyoutFocusFlag) {
# 		var el = $(this);
# 		flyoutHide = setTimeout(function(){
# 			flyoutShownFlag = false;
# 			el.removeClass('adv_flyout--full');
# 		},1000);
# 	}
# 	return false
# });
#
# var fElems = $('.adv_flyout__content').find('input, select, button, textarea');
# fElems.on('focus', function(){
# 	$(this).closest('.adv_flyout').addClass('adv_flyout--full');
# 	flyoutFocusFlag = true;
# 	return false
# });
# fElems.on('focusout', function(){
# 	$(this).closest('.adv_flyout').removeClass('adv_flyout--full');
# 	flyoutShownFlag = false;
# 	flyoutFocusFlag = false;
# 	return false
# });
# });
#     </script>
#    </div>
#    <div class="footer">
#     <div class="footer__inner row">
#      <div class="footer__border">
#      </div>
#      <div class="footer__breadcrumbs">
#       <a class="link no-visited" href="//www.hse.ru">
#        Национальный исследовательский университет «Высшая школа экономики»
#       </a>
#       →
#       <a class="link no-visited" href="https://www.hse.ru/education/bachelor/">
#        Образовательные программы бакалавриата
#       </a>
#       →
#       <a class="link no-visited" href="https://cs.hse.ru/">
#        Факультет компьютерных наук
#       </a>
#       →
#       <span class="b">
#        Образовательная программа «Прикладная математика и информатика»
#       </span>
#      </div>
#      <div class="footer__navigation">
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/org/hse/info/">
#          О Вышке
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/figures/">
#          Цифры и факты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/orgstructure/">
#          Руководство и структура
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/org/persons/">
#          Преподаватели и сотрудники
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/buildinghse">
#          Корпуса и общежития
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/org/hse/aup/procurement/">
#          Закупки
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/appeal/">
#          Обращения граждан в НИУ ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//endowment.hse.ru/">
#          Фонд целевого капитала
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/anticorruption">
#          Противодействие коррупции
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/anticorruption/information">
#          Сведения о доходах, расходах, об имуществе и обязательствах имущественного характера
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/sveden/">
#          Сведения об образовательной организации
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://inclusive.hse.ru/">
#          ВШЭ для людей с ограниченными возможностями здоровья и инвалидов
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://pay.hse.ru/">
#          Единая платежная страница
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/education/">
#          ОБРАЗОВАНИЕ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//school.hse.ru">
#          Лицей
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://fdp.hse.ru/">
#          Довузовская подготовка
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//olymp.hse.ru/">
#          Олимпиады
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//ba.hse.ru/">
#          Прием в бакалавриат
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/plus">
#          Вышка+
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//ma.hse.ru/">
#          Прием в магистратуру
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//aspirantura.hse.ru/">
#          Аспирантура
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//busedu.hse.ru/">
#          Дополнительное образование
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://busedu.hse.ru/corporate">
#          Корпоративное обучение
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://career.hse.ru/">
#          Центр развития карьеры
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://careerspace.hse.ru/">
#          Карьерные карты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://inc.hse.ru/">
#          Бизнес-инкубатор ВШЭ
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/science/">
#          НАУКА
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/centers">
#          Научные подразделения
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/org/projects/">
#          Исследовательские проекты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/monitoring/">
#          Мониторинги
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/news/announcements/scientific_actions/">
#          Научные мероприятия
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/disscoun/">
#          Диссертационные советы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://aspirantura.hse.ru/defence/announcements/">
#          Защиты диссертаций
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//academics.hse.ru/">
#          Академическое развитие
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/hsegrants">
#          Конкурсы и гранты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://iq.hse.ru/">
#          Научно-образовательный портал IQ.hse.ru
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://conf.hse.ru/2021">
#          XXII Апрельская международная научная конференция по проблемам развития экономики и общества
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//publications.hse.ru">
#          Ресурсы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://library.hse.ru/">
#          Библиотека
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//id.hse.ru">
#          Издательский дом ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://id.hse.ru/shop/">
#          Книжный интернет-магазин
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//bookshop.hse.ru/">
#          Книжный магазин «БукВышка»
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://print.hse.ru/">
#          Типография
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://mc.hse.ru/">
#          Медиацентр
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/journals">
#          Журналы ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//publications.hse.ru">
#          Публикации
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://sophist.hse.ru/">
#          Единый архив экономических и социологических данных
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://moscow.hse.ru">
#          Университет, открытый городу
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://store.hse.ru/">
#          Магазин HSE STORE
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         Полезные ссылки
#        </li>
#        <li>
#         <a class="link no-visited" href="http://www.minobrnauki.gov.ru/" rel="nofollow">
#          Министерство науки и высшего образования РФ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://edu.gov.ru/" rel="nofollow">
#          Министерство просвещения РФ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://www.edu.ru" rel="nofollow">
#          Федеральный портал «Российское образование»
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://elearning.hse.ru/mooc">
#          Массовые открытые онлайн-курсы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://5top100.ru/" rel="nofollow">
#          Проект 5-100
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://studyinrussia.ru/" rel="nofollow">
#          Study In Russia
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer__extra">
#       <div class="footer__extra-inner">
#        <div class="editor">
#         <!--noindex-->
#         <a class="link link_btm_editor" href="https://www.hse.ru/adm/edit/edit.html?goto=%2AL2JhL2FtaS9yYXRpbmdzP19yPTMzMzk3MzgxNjI2NzgyNzIxLjAzNDE4%5E&amp;id=122722317&amp;cid=22700&amp;addon_name=default&amp;newportal=1">
#          Редактору
#         </a>
#         <!--/noindex-->
#        </div>
#       </div>
#      </div>
#      <div class="footer__bottom">
#       <span class="grey">
#        © НИУ ВШЭ 1993–2021
#       </span>
#       <a href="https://www.hse.ru/contacts.html">
#        Адреса и контакты
#       </a>
#       <a href="https://www.hse.ru/copyright">
#        Условия использования материалов
#       </a>
#       <a href="https://www.hse.ru/data_protection_regulation">
#        Политика конфиденциальности
#       </a>
#       <a href="https://www.hse.ru/sitemap.html">
#        Карта сайта
#       </a>
#      </div>
#     </div>
#     <svg class="svg-mask" height="0" width="0" xmlns:xlink="http://www.w3.org/1999/xlink">
#      <defs>
#       <clippath id="hse-mask">
#        <use x="0" xlink:href="#hse-mask-path" y="0">
#        </use>
#       </clippath>
#       <path d="M0,70 M64.979,3.055l-25.904,0.05 c-21.8,0-36.163,11.798-36.163,31.612c0,19.389,13.387,32.251,35.769,32.251c13.183,0,30.315-0.071,30.315-0.071l-4.029-5.025 L64.979,3.055L64.979,3.055z" fill="none" id="hse-mask-path" stroke="#000" stroke-opacity="0.3" stroke-width="1">
#       </path>
#      </defs>
#     </svg>
#    </div>
#   </div>
#   <div class="popups">
#   </div>
#  </body>
# </html>

# %% [markdown]
# Тем же методом пристального взгляда находим блок, хранящий все доступные на данный момент рейтинги:

# %%
options = soup('div', 'first_child last_child')
options[0]('select')[0]('option')
# Out:
# [<option selected="" value="488315638">Текущий рейтинг 2020/2021 учебного года (3-4 модули)</option>,
#  <option value="488315636">Рейтинг выпускников 2020/2021 уч.г.</option>,
#  <option value="454146718">Кумулятивный рейтинг по итогам 1-2 модулей 2020/2021 уч.г.</option>,
#  <option value="450612123">Текущий рейтинг после пересдач 2020/2021 учебного года (1-2 модули)</option>,
#  <option value="436052040">Текущий рейтинг 2020/2021 учебного года (1-2 модули)</option>,
#  <option value="436052038">Рейтинг выпускников 2019/2020 уч.г.</option>,
#  <option value="414185556">Кумулятивный рейтинг по итогам 3-4 модулей 2019/2020 уч.г.</option>,
#  <option value="412769365">Текущий рейтинг после пересдач 2019/2020 учебного года (3-4 модули)</option>,
#  <option value="381346749">Текущий рейтинг 2019/2020 учебного года (3-4 модули)</option>,
#  <option value="351900289">Кумулятивный рейтинг по итогам 1-2 модулей 2019/2020 уч.г.</option>,
#  <option value="348116371">Текущий рейтинг после пересдач 2019/2020 учебного года (1-2 модули)</option>,
#  <option value="334268420">Текущий рейтинг 2019/2020 учебного года (1-2 модули)</option>,
#  <option value="318775745">Кумулятивный рейтинг по итогам 3-4 модулей 2018/2019 уч.г.</option>,
#  <option value="316264576">Текущий рейтинг после пересдач 2018/2019 уч.г. (3-4 модули)</option>,
#  <option value="298519626">Текущий рейтинг 2018/2019 учебного года (3-4 модули)</option>,
#  <option value="298334411">Рейтинг выпускников 2018/2019 уч.г.</option>,
#  <option value="251826638">Кумулятивный рейтинг по итогам 1-2 модулей 2018/2019 уч.г.</option>,
#  <option value="251363918">Текущий рейтинг после пересдач 2018/2019уч.г. (1-2 модули)</option>,
#  <option value="233106664">Текущий рейтинг 2018/2019уч.г. (1 семестр)</option>]

# %% [markdown]
# и номера курсов:

# %%
for option in options[0]('select')[1]('option'):
    print(option['value'])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Как видим, у каждого рейтинга есть своё ```value```, которое как раз нужно для того, чтобы получить страницу с соответствующим рейтингом:

# %%
url_from = None
for rating in options[0]('option'):
    if rating.text == query_rating:
        url_from = rating['value']
        break
rating_url = f'https://www.hse.ru/ba/{code}/ratings?from={url_from}&course={query_course}'
response = requests.get(rating_url)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- (c) Art. Lebedev Studio | http://www.artlebedev.com/ -->
# <html lang="ru" xmlns:perl="urn:perl">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="#1658DA" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/f/src/global/i/favicon/favicon_ios_180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/f/src/global/i/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/f/src/global/i/favicon/favicon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#242f63" href="/f/src/global/i/favicon/favicon.svg" rel="mask-icon"/>
#   <link href="/f/src/manifest/manifest_ru.json" rel="manifest"/>
#   <meta content="/f/src/global/i/favicon/browserconfig.xml" name="msapplication-config"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->
#   <link href="/f/src/global/css/main.css?v2" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/vision.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/sitemap.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/fotorama.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/global/css/owl.carousel2.min.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/edu_card/edu_card.css?v3" media="all" rel="stylesheet"/>
#   <link href="/f/src/promo/gallery-promo.css" media="all" rel="stylesheet"/>
#   <link href="/f/src/postupi/postupi.css" media="all" rel="stylesheet"/>
#   <script src="//www.hse.ru/f/src/global/js/cache/jquery-1.12.4.min/jquery-ui/jquery.ui.touch-punch.min/hse.utils/errtrack/main/modernizr/popup/switcher/tag/fixes/email-obfuscator/jquery.cookie/vision/jquery.rwdImageMaps.min/sitemap.ajax/fotorama/slider/jquery.menu-aim/menu-aim-init/jquery.carouFredSel-6.2.1-packed/hs/mag/init-social-carousel/init-media-carousel/owl.carousel2.min/edu-card/edu_mobile.js">
#   </script>
#   <script src="/f/src/global/js/gibs.js">
#   </script>
#   <script src="/f/src/student-ratings/student-ratings.js">
#   </script>
#   <link href="/f/src/student-ratings/student-ratings.css" media="all" rel="stylesheet"/>
#   <script async="async" src="https://www.hse.ru/f/src/global/js/job.js">
#   </script>
#   <title>
#    Образовательная программа «Прикладная математика и информатика» — Национальный исследовательский университет «Высшая школа экономики»
#   </title>
#   <script src="/f/gtm/ip">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-P6DCQX');
#   </script>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" property="og:title"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" name="mrc__share_title"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" itemprop="name"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Образовательная программа «Прикладная математика и информатика»" name="twitter:title"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" property="og:description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" name="mrc__share_description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" itemprop="description"/>
#   <meta content="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»)." name="twitter:description"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" property="og:image"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" itemprop="image"/>
#   <link content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" rel="image_src"/>
#   <meta content="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" name="twitter:image"/>
#   <meta content="https://www.hse.ru/ba/ami/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.hse.ru/ba/ami/" name="twitter:url"/>
#   <link href="/f/src/projects/edu_card/mobile.css" rel="stylesheet"/>
#   <script>
#    $(function() {
# 				if ($('.from-group').length > 0 ) {
# 					$('.from-group').carouFredSel({
# 						auto: false,
# 						width: '99%',
# 						height: 'auto',
# 						scroll: 2,
# 						align: 'center',
# 						items: {
# 				 			width: '200',
# 							visible: {
# 								min: 1,
# 								max: 6
# 							}
# 						},
# 						next: {
# 							button: function() { return $(this).parent().siblings(".b-group-next")},
# 							key: 'right'
# 						},
# 						prev: {
# 							button: function() { return $(this).parent().siblings(".b-group-prev")},
# 							key: 'left'
# 						}
# 					});
# 				}
# 			});
#   </script>
#  </head>
#  <body data-lang="ru" data-unit="122722317">
#   <div class="page">
#    <!--noindex-->
#    <div class="browser_outdate" style="display:none;">
#     В старых версиях браузеров сайт может отображаться некорректно. Для оптимальной работы с сайтом рекомендуем воспользоваться современным браузером.
#    </div>
#    <div class="gdpr_bar" style="display:none;">
#     <div class="gdpr_bar__inner">
#      <noindex>
#       <p class="first_child last_child">
#        Мы используем файлы cookies для улучшения работы сайта НИУ ВШЭ и большего удобства его использования. Более подробную информацию об использовании файлов cookies можно найти
#        <a class="link" href="https://www.hse.ru/cookie.html" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        , наши правила обработки персональных данных –
#        <a class="link" href="https://www.hse.ru/data_protection_regulation" target="_blank" title="Пройти по ссылке">
#         здесь
#        </a>
#        . Продолжая пользоваться сайтом, вы подтверждаете, что были проинформированы об использовании файлов cookies сайтом НИУ ВШЭ и согласны с нашими правилами обработки персональных данных. Вы можете отключить файлы cookies в настройках Вашего браузера.
#       </p>
#      </noindex>
#      <span class="gdpr_bar__close">
#       ✖
#      </span>
#     </div>
#    </div>
#    <!--/noindex-->
#    <div class="sv-control">
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-size">
#       <li class="sv-control__item sv-control__item--s_normal active" data-type="size" data-value="normal">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_medium" data-type="size" data-value="medium">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_large" data-type="size" data-value="large">
#        A
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-spacing">
#       <li class="active sv-control__item sv-control__item--ls_normal" data-type="spacing" data-value="normal">
#        АБВ
#       </li>
#       <li class="sv-control__item sv-control__item--ls_medium" data-type="spacing" data-value="medium">
#        АБВ
#       </li>
#       <li class="sv-control__item sv-control__item--ls_large" data-type="spacing" data-value="large">
#        АБВ
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-contrast">
#       <li class="sv-control__item sv-control__item---color1 active" data-type="contrast" data-value="normal">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color2" data-type="contrast" data-value="invert">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color3" data-type="contrast" data-value="blue">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color4" data-type="contrast" data-value="beige">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color5" data-type="contrast" data-value="brown">
#        А
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-image">
#       <li class="sv-control__item sv-control__item--image_on active" data-type="image" data-value="on">
#        <li class="sv-control__item sv-control__item--image_off" data-type="image" data-value="off">
#        </li>
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <div class="sv-off js-sv-off">
#       Обычная версия сайта
#      </div>
#     </div>
#    </div>
#    <div class="fa-sidebar">
#     <div class="fa-sidebar__top fa-sidebar__top--overlay fa-sidebar__top--secondary" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#      <div class="fa-sidebar__controls is-mobile">
#       <ul class="control_lang2">
#        <li class="control_lang2_item first_child activated">
#         <span class="link link_no-visited link_no-underline">
#          RU
#         </span>
#        </li>
#        <li class="control_lang2_item last_child">
#         <a class="link link_no-visited link_no-underline" href="https://www.hse.ru/en/ba/ami/ratings">
#          EN
#         </a>
#        </li>
#       </ul>
#       <a class="control control_user control_white" href="//www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#        <ins>
#         <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#          <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#          </path>
#         </svg>
#        </ins>
#       </a>
#       <span class="control control_search control_white js-search_mobile_control">
#        <ins>
#         <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#          <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#          </path>
#         </svg>
#        </ins>
#       </span>
#       <span class="control is-mobile control_menu control_menu--close js-control_menu_close" onclick="void(0)" style="cursor:pointer;">
#        <ins>
#        </ins>
#       </span>
#      </div>
#      <div class="js-search_mobile_popup not_display is-mobile">
#       <div class="search-form">
#        <form action="/search/search.html">
#         <div class="search-form__button">
#          <button class="button button--merged button_grey">
#           Найти
#          </button>
#         </div>
#         <div class="search-form__input">
#          <input class="input fa-search_input input100 input_mr" name="text" placeholder="Поиск по сайту" type="text"/>
#          <input name="simple" type="hidden" value="1"/>
#         </div>
#        </form>
#       </div>
#       <div class="popup__block">
#        <a class="link link_white no-visited" href="//www.hse.ru/search/search.html?simple=0">
#         Расширенный поиск по сайту
#        </a>
#       </div>
#      </div>
#      <div class="fa-sidebar__title_inner">
#       <a class="link_white link_no-underline no-visited" href="https://www.hse.ru/ba/ami">
#        Бакалаврская программа «Прикладная математика и информатика»
#       </a>
#      </div>
#     </div>
#     <ul class="fa-sidemenu fa-sidemenu--primary">
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         О программе
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/about">
#          О программе
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/pilot">
#          Пилотный поток
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/features">
#          Особенности программы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/faculty12">
#          Лекторы 1-2 курсов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://www.hse.ru/ba/ami/projects">
#          Проектная и научная работа
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/spec">
#          О специализациях
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://cs.hse.ru/electives" target="_blank">
#          Факультативы ФКН
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/partners">
#          Партнеры
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/success">
#          Достижения студентов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://cs.hse.ru/alumni/">
#          Выпускники
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Абитуриентам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 selected fa-sidemenu__link" href="https://www.hse.ru/ba/ami/admission/">
#          Паспорт программы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/tracks">
#          Траектории поступления
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/applicantvoc">
#          Карманный словарь абитуриента
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/requirements">
#          Подготовка
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/1scholarships">
#          Стипендии для поступивших
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/test">
#          Тестирование по математике и программированию
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/career">
#          Будущая профессия
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://fdp.hse.ru/ischool/">
#          Онлайн-подготовка
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Студентам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 selected fa-sidemenu__link" href="https://www.hse.ru/ba/ami/students/">
#          Доска объявлений
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="http://electives.hse.ru/">
#          Выбор траектории обучения
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://electives.hse.ru/" target="_blank">
#               Общеуниверситетские курсы
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/org/hse/elective_courses/MN_OI" target="_blank">
#               Майноры
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/21-22-767b7191bb8c4a4c96b0c33fa3b27ad8" rel="nofollow" target="_blank">
#          Курсы по выбору 2021-22
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/2021-af3df9c18e664fc08cacc4ab1df51396" rel="nofollow" target="_blank">
#          Специализации
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/theses">
#          Курсовые и ВКР
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/theses21">
#               Курсовые работы
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/vkr">
#               Выпускные квалификационные работы
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/internships">
#          Практика
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/practiceami2">
#               Учебная практика (1 курс)
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/internships">
#               Производственная практика (3 курс)
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/diplomapractice">
#               Преддипломная практика
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent">
#          Проекты
#         </span>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/projectwork">
#               Программный проект 2 курса
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.notion.so/Project-Proposal-0aa7fa0dd99a4a6abbe6ed19e65b7c03" rel="nofollow">
#          Project Proposal
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/assessment">
#          Итоговая аттестация
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/diplomas">
#          Каталог ВКР
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent">
#          Расписание
#         </span>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/scheduletable">
#               Расписание онлайн
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/examschedule">
#               Расписание экзаменов
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/resit">
#               Расписание пересдач
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/grafik">
#               График учебного процесса
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://cs.hse.ru/electives" target="_blank">
#          Факультативы ФКН
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link fa-sidemenu__link--parent" href="https://www.hse.ru/ba/ami/tests">
#          Первокурсникам
#         </a>
#         <i class="fa-sidemenu__arr">
#         </i>
#         <div class="fa-sidemenu__popup">
#          <div class="fa-sidemenu__sub">
#           <div class="fa-sidemenu__section">
#            <ul class="fa-sidemenu">
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/tests">
#               Тестирование первокурсников
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/1year" target="_blank">
#               To Do List первокурсника ПМИ
#              </a>
#             </li>
#             <li class="fa-sidemenu__item">
#              <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/orientationweek">
#               БЖД
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/transfer">
#          Перевод и восстановление на программу
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/moocs">
#          Рекомендованные онлайн-курсы
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/mobility">
#          Студенческая мобильность
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/ratings">
#          Рейтинги
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/hselang/">
#          Дополнительные иностранные языки
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/safety" target="_blank">
#          Мониторинг здоровья студентов
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <span class="link link_no-underline link_dark2 fa-sidemenu__link">
#         </span>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://www.hse.ru/ba/ami/is">
#          Иностранные студенты
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section">
#       <div class="fa-sidemenu__header">
#        <span>
#         Выпускникам
#        </span>
#       </div>
#       <ul class="fa-sidemenu__sub">
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://cs.hse.ru/alumni/">
#          Общая информация
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="http://family.hse.ru/">
#          Вышка.Family
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://career.hse.ru/">
#          Центр развития карьеры
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/">
#          Центр по работе с выпускниками
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/propusk_hse">
#          Пропуск выпускника
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/ambassadors">
#          HSE Alumni Ambassadors
#         </a>
#        </li>
#        <li class="fa-sidemenu__item">
#         <a class="link link_no-underline link_dark2 fa-sidemenu__link" href="https://alumni.hse.ru/fellowship/">
#          HSE Alumni Academic Fellowship
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="fa-sidemenu__section fa-sidemenu__section--add js-sidemenu__section--add">
#      </li>
#     </ul>
#    </div>
#    <div class="header" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#     <div class="crop">
#      <div class="header-top header-top--stoped links-white" style="background-image:url('/mirror/pubs/share/direct/463746598.jpg');">
#       <div class="left">
#        <span class="control control_sitemap">
#         <span class="control_sitemap__line">
#         </span>
#        </span>
#        <a class="control control_home_white" href="//www.hse.ru/">
#         <ins>
#          <svg height="26" viewbox="0 0 18 26" width="18" xmlns="http://www.w3.org/2000/svg">
#           <path d="M6.66 0l.134.002h1.336c2.639 0 3.745.464 4.994 1.428 1.819 1.424 2.105 3.492 2.105 4.525 0 1.283-.393 2.638-1.356 3.742-.714.856-1.955 2.097-4.388 2.388-1.663.2-2.891.127-3.506.061v-1.306c.273.038.676.074 1.222.074 1.656 0 2.829-.827 3.543-1.719.81-.983.98-1.909 1.015-2.737h-4.555v-1.282h4.515c-.116-.866-.448-1.528-.985-2.179-1.035-1.283-2.499-1.497-3.462-1.497l-6.505-.002-.768-1.498h6.66zm-6.317 26l.804-1.564v-21.844h3.55v21.82h2.508v-8.523h3.276v8.514h2.838v-3.878c0-2.351-.122-5.622-2.77-7.311l1.542-.566c3.194 1.186 4.791 4.283 4.791 8.362v3.428l.804 1.562h-17.344z" fill="#1658DA">
#           </path>
#          </svg>
#         </ins>
#        </a>
#       </div>
#       <div class="right">
#        <div class="header__controls">
#         <ul class="control_lang2">
#          <li class="control_lang2_item first_child activated">
#           <span class="link link_no-visited link_no-underline">
#            RU
#           </span>
#          </li>
#          <li class="control_lang2_item last_child">
#           <a class="link link_no-visited link_no-underline" href="https://www.hse.ru/en/ba/ami/ratings">
#            EN
#           </a>
#          </li>
#         </ul>
#         <span class="control control_vision control_white" title="Версия для слабовидящих">
#          <svg height="12" viewbox="0 0 21 12" width="21" xmlns="http://www.w3.org/2000/svg">
#           <path d="M10.5 0c3.438 0 6.937 2.016 10.5 6.047-.844.844-1.383 1.375-1.617 1.594-.234.219-.805.703-1.711 1.453-.906.75-1.641 1.266-2.203 1.547-.563.281-1.305.578-2.227.891-.922.313-1.836.469-2.742.469-1.125 0-2.156-.141-3.094-.422-.938-.281-1.875-.766-2.813-1.453-.938-.688-1.672-1.273-2.203-1.758-.531-.484-1.328-1.273-2.391-2.367 2.031-2.031 3.836-3.539 5.414-4.523 1.578-.984 3.273-1.477 5.086-1.477zm0 10.266c1.156 0 2.148-.422 2.977-1.266.828-.844 1.242-1.844 1.242-3s-.414-2.156-1.242-3c-.828-.844-1.82-1.266-2.977-1.266-1.156 0-2.148.422-2.977 1.266-.828.844-1.242 1.844-1.242 3s.414 2.156 1.242 3c.828.844 1.82 1.266 2.977 1.266zm0-5.766c0 .438.141.797.422 1.078s.641.422 1.078.422c.313 0 .625-.109.938-.328v.328c0 .688-.234 1.273-.703 1.758-.469.484-1.047.727-1.734.727-.688 0-1.266-.242-1.734-.727-.469-.484-.703-1.07-.703-1.758s.234-1.273.703-1.758c.469-.484 1.047-.727 1.734-.727h.375c-.25.313-.375.641-.375.984z" fill="#1658DA">
#           </path>
#          </svg>
#         </span>
#         <a class="control control_user control_white" href="//www.hse.ru/user/" title="Личный кабинет сотрудника ВШЭ">
#          <ins>
#           <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#            <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#         </a>
#         <span class="control control_search control_white" title="Поиск">
#          <ins class="popup_opener">
#           <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#            <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#          <div class="popup popup_search not_display">
#           <div class="popup__inner">
#            <div class="search-form">
#             <form action="https://www.hse.ru/ba/ami/search/search.html">
#              <div class="search-form__button">
#               <button class="button button_grey">
#                Найти
#               </button>
#              </div>
#              <div class="search-form__input">
#               <input class="input input100 input_mr" name="text" placeholder="Поиск по сайту" type="text"/>
#               <input name="simple" type="hidden" value="1"/>
#               <input name="searchid" type="hidden" value="2284688"/>
#              </div>
#             </form>
#            </div>
#            <div class="popup__block popup__block_indent">
#             <a class="link link_dark no-visited" href="//www.hse.ru/search/search.html?simple=0&amp;searchid=2284688">
#              Расширенный поиск по сайту
#             </a>
#             <span class="b-adv-search">
#             </span>
#            </div>
#           </div>
#          </div>
#         </span>
#         <span class="control is-mobile control_menu js-control_menu_open" onclick="void(0)" style="cursor:pointer;">
#          <ins>
#          </ins>
#          <span class="control__text">
#           Меню
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="header_body">
#        <div class="header_breadcrumb">
#         <div class="header_breadcrumb__inner is-mobile no_crumb_arrow">
#          <a class="link_white no-visited link" href="https://www.hse.ru">
#           Высшая школа экономики
#          </a>
#         </div>
#         <div class="header_breadcrumb__inner is-desktop no_crumb_arrow">
#          <ul class="header_breadcrumb__list">
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="//www.hse.ru">
#             <span>
#              Национальный исследовательский университет «Высшая школа экономики»
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="https://www.hse.ru/education/bachelor/">
#             <span>
#              Образовательные программы бакалавриата
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <a class="link no-visited header_breadcrumb__link" href="https://cs.hse.ru/">
#             <span>
#              Факультет компьютерных наук
#             </span>
#            </a>
#           </li>
#           <li class="header_breadcrumb__item">
#            <span>
#             <span class="breadcrumb_current">
#              Образовательная программа «Прикладная математика и информатика»
#             </span>
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header-board row">
#       <div class="extra-left">
#        <div class="header-content">
#         <h2 class="h1">
#          <a class="link_white link_no-underline no-visited" href="https://www.hse.ru/ba/ami">
#           Бакалаврская программа «Прикладная математика и информатика»
#          </a>
#         </h2>
#         <div class="menu edu-menu">
#          <ul class="navigation navigation_horizontal navigation_newl">
#           <li class="single">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/">
#             <span class="link">
#              <span class="icon icon-home">
#               <svg height="15" viewbox="0 0 16 15" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path d="M6.122 14.692h-3.75V7.346H0L7.958 0l7.959 7.346h-2.373v7.346h-3.75V9.795H6.123z" fill="#FFF" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/about/">
#             <span class="link">
#              О программе
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select0">
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/about">
#               <span class="link">
#                О программе
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/pilot">
#               <span class="link">
#                Пилотный поток
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/features">
#               <span class="link">
#                Особенности программы
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/faculty12">
#               <span class="link">
#                Лекторы 1-2 курсов
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://www.hse.ru/ba/ami/projects">
#               <span class="link">
#                Проектная и научная работа
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/spec">
#               <span class="link">
#                О специализациях
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://cs.hse.ru/electives" target="_blank">
#               <span class="link">
#                Факультативы ФКН
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/partners">
#               <span class="link">
#                Партнеры
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/success">
#               <span class="link">
#                Достижения студентов
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="http://cs.hse.ru/alumni/">
#               <span class="link">
#                Выпускники
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="">
#            <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/admission/">
#             <span class="link">
#              Абитуриентам
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select0">
#             <li>
#              <a class="link" href="https://www.hse.ru/ba/ami/admission/">
#               Паспорт программы
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/tracks">
#               <span class="link">
#                Траектории поступления
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/applicantvoc">
#               <span class="link">
#                Карманный словарь абитуриента
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/requirements">
#               <span class="link">
#                Подготовка
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/1scholarships">
#               <span class="link">
#                Стипендии для поступивших
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/test">
#               <span class="link">
#                Тестирование по математике и программированию
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/career">
#               <span class="link">
#                Будущая профессия
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://fdp.hse.ru/ischool/">
#               <span class="link">
#                Онлайн-подготовка
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="selected">
#            <a class="link link_no-underline selected" href="https://www.hse.ru/ba/ami/students/">
#             <span class="link">
#              Студентам
#             </span>
#            </a>
#            <i class="nav-arr">
#            </i>
#            <ul class="navigation_newl-sub navigation_newl-sub_1 navigation_newl-select0">
#             <li>
#              <a class="link" href="https://www.hse.ru/ba/ami/students/">
#               Доска объявлений
#              </a>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="http://electives.hse.ru/">
#               <span class="link pseudo_link sub_link">
#                Выбор траектории обучения
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="http://electives.hse.ru/" target="_blank">
#                 <span class="link">
#                  Общеуниверситетские курсы
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/org/hse/elective_courses/MN_OI" target="_blank">
#                 <span class="link">
#                  Майноры
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.notion.so/21-22-767b7191bb8c4a4c96b0c33fa3b27ad8" rel="nofollow" target="_blank">
#               <span class="link">
#                Курсы по выбору 2021-22
#               </span>
#              </a>
#             </li>
#             <li class="single">
#              <a class="link link_no-underline" href="https://www.notion.so/2021-af3df9c18e664fc08cacc4ab1df51396" rel="nofollow" target="_blank">
#               <span class="link">
#                Специализации
#               </span>
#              </a>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/theses">
#               <span class="link pseudo_link sub_link">
#                Курсовые и ВКР
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/theses21">
#                 <span class="link">
#                  Курсовые работы
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/vkr">
#                 <span class="link">
#                  Выпускные квалификационные работы
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/internships">
#               <span class="link pseudo_link sub_link">
#                Практика
#               </span>
#              </a>
#              <i class="nav-arr">
#              </i>
#              <ul class="navigation_newl-sub navigation_newl-sub_2 navigation_newl-select0">
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/practiceami2">
#                 <span class="link">
#                  Учебная практика (1 курс)
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/internships">
#                 <span class="link">
#                  Производственная практика (3 курс)
#                 </span>
#                </a>
#               </li>
#               <li class="single">
#                <a class="link link_no-underline" href="https://www.hse.ru/ba/ami/diplomapractice">
#                 <span class="link">
#                  Преддипломная практика
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="">
#              <a class="link link_no-underline" href="">
#               <span class="link pseudo_link sub_link">
# ...
#                290
#               </td>
#               <td class="p2 special-table__cell special-table__cell--grade_mid">
#                5.33
#               </td>
#               <td class="p3 special-table__cell special-table__cell--grade_min">
#                4
#               </td>
#               <td class="p4 special-table__cell special-table__cell--percentil">
#                99.66%
#               </td>
#               <td class="p5 special-table__cell special-table__cell--grade_gpa">
#                4.38
#               </td>
#              </tr>
#             </table>
#             <p>
#              <a class="link" href="https://www.hse.ru/ba/ami/ratings/archive">
#               Рейтинги студентов за предыдущие периоды
#              </a>
#             </p>
#             <p>
#              Расчет и публикация рейтингов студентов осуществляется на основании
#              <a class="link" href="https://www.hse.ru/docs/295301710.html">
#               Положения о рейтинговой системе комплексной оценки знаний студентов образовательных программ бакалавриата, специалитета и магистратуры Национального исследовательского университета «Высшая школа экономики»
#              </a>
#             </p>
#             <p class="last_child">
#              Детализированная информация по оценкам доступна каждому студенту и преподавателям НИУ ВШЭ через систему LMS
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="post post_single3 addthiscode">
#          <div class="post__content">
#           <script async="async" charset="utf-8" src="//yastatic.net/share2/share.js" type="text/javascript">
#           </script>
#           <div class="ya-share2" data-description="Программа готовит инженеров-исследователей, инженеров-разработчиков в области теоретической и прикладной информатики («Computer Science»). Программа разработана с учётом опыта факультетов компьютерных наук университетов EPFL в Швейцарии и Stanford в США, а также Школы анализа данных Яндекса" data-image="https://www.hse.ru/data/2021/02/14/1321638623/orig.jpg" data-lang="ru" data-limit="6" data-services="facebook,vkontakte,twitter,telegram,whatsapp,viber" data-title="Образовательная программа «Прикладная математика и информатика»" data-url="https://www.hse.ru/ba/ami/">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--banner -->
#     <a class="adv_flyout adv_flyout--banner link_no-underline" href="https://studyabroad.hse.ru/catalogue/" style="top: 45%">
#      <div class="adv_flyout__corner" style=" background-color: #9d2004;">
#      </div>
#      <div class="adv_flyout__content links-white adv_flyout__content--banner" style="background-color: #9d2004">
#       <div class="adv_flyout__content_inner" style="background-image: url(/pubs/share/direct/218771813.jpg);">
#       </div>
#      </div>
#     </a>
#     <style>
#      .adv_flyout {
# 		display: flex;
# 		height: 90px;
# 		visibility: hidden;
# 		margin: 20px 0;
# 	}
# 	.adv_flyout__corner {
# 		display: none;
# 		width: 30px;
# 		height: 90px;
# 		flex: 0 0 30px;
# 		background: center #1658DA no-repeat;
# 		background-size: cover;
# 	}
# 	.adv_flyout__content {
# 		flex: 1 1 auto;
# 		background-color: #1658DA;
# 	}
# 	.adv_flyout__content_inner {
# 		padding: .7em;
# 		background: center no-repeat;
# 		background-size: cover;
# 		background-color: inherit;
# 		color: #fff;
# 		box-sizing: border-box;
# 	}
# 	.adv_flyout--banner  .adv_flyout__content_inner {
# 		height: 90px;
# 	}
# 	.adv_flyout *:first-child {
# 		margin-top: 0;
# 	}
# 	@media (min-width: 768px) {
# 		.adv_flyout {
# 			position: fixed;
# 			z-index: 5;
# 			width: 269px;
# 			right: -239px;
# 			top: 30%;
# 			transition: right .5s ease 0s;
# 			padding: 0;
# 			margin: 0;
# 		}
#
# 		.adv_flyout--minimize.adv_flyout--minimize {
# 			right: -239px;
# 		}
# 		.adv_flyout--full.adv_flyout--full {
# 			right: 0;
# 		}
# 		.adv_flyout__corner {
# 			display: block;
# 			position: absolute;
# 			top: 0;
# 			left: 0;
# 		}
# 		.adv_flyout--full .adv_flyout__corner {
# 			cursor: pointer;
# 		}
# 		.adv_flyout__content {
# 			margin-left: 30px;
# 		}
# 	}
# 	@media (max-width: 767px) {
# 		.adv_flyout {
# 			height: auto;
# 		}
# 	}
#     </style>
#     <script>
#      $(function() {
# function LoadImage() {
# 	var img = new Image();
# 	img.onload = function() {
# 		setTimeout(function(){
# 			//IE
# 			if (!('remove' in Element.prototype)) {
# 				Element.prototype.remove = function() {
# 					if (this.parentNode) {
# 						this.parentNode.removeChild(this);
# 					}
# 				};
# 			}
#
# 			img.remove();
# 			$('.adv_flyout').css('visibility','visible');
# 		}, (parseFloat(3, 10) * 1000));
# 	};
# 	img.src = "/pubs/share/direct/218771813.jpg";
# }
# LoadImage();
#
# var flyoutShownFlag = false;
# var flyoutFocusFlag = false;
# var flyoutHide;
# $('.adv_flyout').hover(function() {
# 	if(!flyoutShownFlag) {
# 		$(this).addClass('adv_flyout--full');
# 		flyoutShownFlag = true;
# 	}
# 	clearTimeout(flyoutHide);
# 	return false
# },function(){
# 	if(!flyoutFocusFlag) {
# 		var el = $(this);
# 		flyoutHide = setTimeout(function(){
# 			flyoutShownFlag = false;
# 			el.removeClass('adv_flyout--full');
# 		},1000);
# 	}
# 	return false
# });
#
# var fElems = $('.adv_flyout__content').find('input, select, button, textarea');
# fElems.on('focus', function(){
# 	$(this).closest('.adv_flyout').addClass('adv_flyout--full');
# 	flyoutFocusFlag = true;
# 	return false
# });
# fElems.on('focusout', function(){
# 	$(this).closest('.adv_flyout').removeClass('adv_flyout--full');
# 	flyoutShownFlag = false;
# 	flyoutFocusFlag = false;
# 	return false
# });
# });
#     </script>
#    </div>
#    <div class="footer">
#     <div class="footer__inner row">
#      <div class="footer__border">
#      </div>
#      <div class="footer__breadcrumbs">
#       <a class="link no-visited" href="//www.hse.ru">
#        Национальный исследовательский университет «Высшая школа экономики»
#       </a>
#       →
#       <a class="link no-visited" href="https://www.hse.ru/education/bachelor/">
#        Образовательные программы бакалавриата
#       </a>
#       →
#       <a class="link no-visited" href="https://cs.hse.ru/">
#        Факультет компьютерных наук
#       </a>
#       →
#       <span class="b">
#        Образовательная программа «Прикладная математика и информатика»
#       </span>
#      </div>
#      <div class="footer__navigation">
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/org/hse/info/">
#          О Вышке
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/figures/">
#          Цифры и факты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/orgstructure/">
#          Руководство и структура
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/org/persons/">
#          Преподаватели и сотрудники
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/buildinghse">
#          Корпуса и общежития
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/org/hse/aup/procurement/">
#          Закупки
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/appeal/">
#          Обращения граждан в НИУ ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//endowment.hse.ru/">
#          Фонд целевого капитала
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/anticorruption">
#          Противодействие коррупции
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/anticorruption/information">
#          Сведения о доходах, расходах, об имуществе и обязательствах имущественного характера
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/sveden/">
#          Сведения об образовательной организации
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://inclusive.hse.ru/">
#          ВШЭ для людей с ограниченными возможностями здоровья и инвалидов
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://pay.hse.ru/">
#          Единая платежная страница
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/education/">
#          ОБРАЗОВАНИЕ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//school.hse.ru">
#          Лицей
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://fdp.hse.ru/">
#          Довузовская подготовка
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//olymp.hse.ru/">
#          Олимпиады
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//ba.hse.ru/">
#          Прием в бакалавриат
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/plus">
#          Вышка+
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//ma.hse.ru/">
#          Прием в магистратуру
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//aspirantura.hse.ru/">
#          Аспирантура
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//busedu.hse.ru/">
#          Дополнительное образование
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://busedu.hse.ru/corporate">
#          Корпоративное обучение
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://career.hse.ru/">
#          Центр развития карьеры
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://careerspace.hse.ru/">
#          Карьерные карты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://inc.hse.ru/">
#          Бизнес-инкубатор ВШЭ
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//www.hse.ru/science/">
#          НАУКА
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/centers">
#          Научные подразделения
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/org/projects/">
#          Исследовательские проекты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/monitoring/">
#          Мониторинги
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://www.hse.ru/news/announcements/scientific_actions/">
#          Научные мероприятия
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/disscoun/">
#          Диссертационные советы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://aspirantura.hse.ru/defence/announcements/">
#          Защиты диссертаций
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//academics.hse.ru/">
#          Академическое развитие
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/hsegrants">
#          Конкурсы и гранты
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://iq.hse.ru/">
#          Научно-образовательный портал IQ.hse.ru
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://conf.hse.ru/2021">
#          XXII Апрельская международная научная конференция по проблемам развития экономики и общества
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         <a class="link link_dark title no-visited" href="//publications.hse.ru">
#          Ресурсы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://library.hse.ru/">
#          Библиотека
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//id.hse.ru">
#          Издательский дом ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://id.hse.ru/shop/">
#          Книжный интернет-магазин
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//bookshop.hse.ru/">
#          Книжный магазин «БукВышка»
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://print.hse.ru/">
#          Типография
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://mc.hse.ru/">
#          Медиацентр
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//www.hse.ru/science/journals">
#          Журналы ВШЭ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="//publications.hse.ru">
#          Публикации
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://sophist.hse.ru/">
#          Единый архив экономических и социологических данных
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://moscow.hse.ru">
#          Университет, открытый городу
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://store.hse.ru/">
#          Магазин HSE STORE
#         </a>
#        </li>
#       </ul>
#       <ul class="navigation navigation_footer">
#        <li class="parent">
#         Полезные ссылки
#        </li>
#        <li>
#         <a class="link no-visited" href="http://www.minobrnauki.gov.ru/" rel="nofollow">
#          Министерство науки и высшего образования РФ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://edu.gov.ru/" rel="nofollow">
#          Министерство просвещения РФ
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://www.edu.ru" rel="nofollow">
#          Федеральный портал «Российское образование»
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://elearning.hse.ru/mooc">
#          Массовые открытые онлайн-курсы
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="http://5top100.ru/" rel="nofollow">
#          Проект 5-100
#         </a>
#        </li>
#        <li>
#         <a class="link no-visited" href="https://studyinrussia.ru/" rel="nofollow">
#          Study In Russia
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer__extra">
#       <div class="footer__extra-inner">
#        <div class="editor">
#         <!--noindex-->
#         <a class="link link_btm_editor" href="https://www.hse.ru/adm/edit/edit.html?goto=%2AL2JhL2FtaS9yYXRpbmdzP2NvdXJzZT0yJl9yPTMzNDE0OTExNjI2NzgzNTUzLjY1NTMxJmZyb209%5ENDU0MTQ2NzE4%5E&amp;id=122722317&amp;cid=22700&amp;addon_name=default&amp;newportal=1">
#          Редактору
#         </a>
#         <!--/noindex-->
#        </div>
#       </div>
#      </div>
#      <div class="footer__bottom">
#       <span class="grey">
#        © НИУ ВШЭ 1993–2021
#       </span>
#       <a href="https://www.hse.ru/contacts.html">
#        Адреса и контакты
#       </a>
#       <a href="https://www.hse.ru/copyright">
#        Условия использования материалов
#       </a>
#       <a href="https://www.hse.ru/data_protection_regulation">
#        Политика конфиденциальности
#       </a>
#       <a href="https://www.hse.ru/sitemap.html">
#        Карта сайта
#       </a>
#      </div>
#     </div>
#     <svg class="svg-mask" height="0" width="0" xmlns:xlink="http://www.w3.org/1999/xlink">
#      <defs>
#       <clippath id="hse-mask">
#        <use x="0" xlink:href="#hse-mask-path" y="0">
#        </use>
#       </clippath>
#       <path d="M0,70 M64.979,3.055l-25.904,0.05 c-21.8,0-36.163,11.798-36.163,31.612c0,19.389,13.387,32.251,35.769,32.251c13.183,0,30.315-0.071,30.315-0.071l-4.029-5.025 L64.979,3.055L64.979,3.055z" fill="none" id="hse-mask-path" stroke="#000" stroke-opacity="0.3" stroke-width="1">
#       </path>
#      </defs>
#     </svg>
#    </div>
#   </div>
#   <div class="popups">
#   </div>
#  </body>
# </html>

# %% [markdown]
# Осталось найти в этом html-коде, собственно, табличку с рейтингом и вычленить из неё всю информацию:

# %%
names = []
places = []
grade_mids = []
grade_mins = []
percentiles = []
grade_gpas = []

for tr in soup('table')[0]('tr')[1:]:
    names.append(tr('td')[0].text)
    places.append(tr('td')[1].text)
    grade_mids.append(float(tr('td')[2].text))
    grade_mins.append(int(tr('td')[3].text))
    percentiles.append(float(tr('td')[4].text[:-1]))
    grade_gpas.append(float(tr('td')[5].text))

# %% [markdown]
# Соберём из полученных данных ```pandas```-овский датафрейм:

# %%
import pandas as pd


rating = pd.DataFrame(
    {
        'Студент': names,
        'Позиция в рейтинге': places,
        'Средний балл': grade_mids,
        'Минимальный балл': grade_mins,
        'Перцентиль': percentiles,
        'GPA': grade_gpas
    }
)
rating
# Out:
#                               Студент Позиция в рейтинге  Средний балл  \
# 0      Смородинов Александр Андреевич                  1          9.03
# 1       Буклей Григорий Александрович                  2          9.21
# 2          Поздеев Дмитрий Михайлович                  3          9.15
# 3              Иваник Даниил Иванович                  4          9.33
# 4    Колодезный Александр Анатольевич                  5          9.35
# ..                                ...                ...           ...
# 285          Гладких Роман Евгеньевич                286          5.40
# 286       Лукомский Вячеслав Игоревич                287          5.63
# 287          Ярусский Илья Михайлович                288          5.25
# 288         Игнатович Денис Сергеевич                289          5.21
# 289          Еринова Варвара Игоревна                290          5.33
#
#      Минимальный балл  Перцентиль   GPA
# 0                   6        0.00  9.09
# 1                   7        0.34  9.17
# 2                   5        0.69  9.16
# 3                   7        1.03  9.32
# 4                   7        1.38  9.33
# ..                ...         ...   ...
# 285                 4       98.28  5.18
# 286                 4       98.62  5.11
# 287                 4       98.97  4.64
# 288                 4       99.31  4.59
# 289                 4       99.66  4.38
#
# [290 rows x 6 columns]

# %% [markdown]
# и заодно посмотрим на его матрицу корреляций:

# %%
rating.corr()
# Out:
#                   Средний балл  Минимальный балл  Перцентиль       GPA
# Средний балл          1.000000          0.831815   -0.926766  0.993986
# Минимальный балл      0.831815          1.000000   -0.794639  0.817710
# Перцентиль           -0.926766         -0.794639    1.000000 -0.927272
# GPA                   0.993986          0.817710   -0.927272  1.000000

# %% [markdown]
# Весьма близкие по модулю к 1 попарные коэффициенты корреляций между GPA, средним баллом и перцентилем не вызывают удивления: логично, что чем больше средний и средневзвешенный баллы у студента, тем выше он в рейтинге $ \implies $ тем меньше его перцентиль. Однако эти показатели, в свою очередь, не столь сильно коррелируют с минимальным баллом. Это тоже объяснимо: например, у студента могут быть высокие оценки по всем дисциплинам, кроме одной. Понятно, что она не будет вносить существенного вклада (тем более, если весит мало кредитов) в средний балл, и студент всё равно будет довольно высоко в рейтинге.

# %% [markdown]
# ## 2. Написание классов веб-скрапера и функций для сбора данных
#
# Теперь, уже имея представление о том, что делать с нужными нам веб-страницами, реализуем общий интерфейс для получения рейтингов.

# %% [markdown]
# Нам потребуется исключение, которое мы будем кидать в случае, когда не удалось получить запрошенную страницу:

# %%
class BadResponseError(Exception):
    def __init__(self, response_code: int):
        self.response_code = response_code
    
    def __str__(self):
        return f'Bad response status code: {self.response_code}'

# %% [markdown]
# а также класс для парсинга страницы с помощью ```Beautiful Soup```:

# %%
class BeautifulSoupHtmlParser:
    OK_RESPONSE_STATUS = 200
    
    def __init__(self, parser: str):
        self.parser = parser
    
    def __call__(self, url: str) -> BeautifulSoup:
        response = requests.get(url)
        if response.status_code != BeautifulSoupHtmlParser.OK_RESPONSE_STATUS:
            raise BadResponseError(response.status_code)
        return BeautifulSoup(response.content, self.parser)

# %% [markdown]
# **Класс, реализующий скрапинг страницы с образовательными программами:**

# %%
from typing import Tuple, Dict, Set


class HseEduProgramsWebScraper:
    TARGET_TOWNS = ['Москва']
    REGULAR_DOMAINS = ['www.hse.ru']
    URL = 'https://www.hse.ru/education/msk/bachelor/'
    
    @staticmethod
    def sanitize_str(s: str) -> str:
        return s.strip().replace('\xa0', ' ')
        
    def __init__(self):
        self.faculties = {}
        self.programs = {}
        self.loaded = False
        
    def get(self) -> Tuple[Dict[str, Set[str]], Dict[str, str]]:
        if self.loaded:
            return self.faculties, self.programs
        
        parser = BeautifulSoupHtmlParser('html.parser')
        try:
            soup = parser(HseEduProgramsWebScraper.URL)
        except BadResponseError:
            raise
        programs_html = soup('div', id='education-programs__list')[0]
        for program in programs_html('div', 'edu-programm__item'):
            town, faculty = [sanitize_str(program('div', 'edu-programm__unit')[0]('span')[i].text) for i in [0, 1]]
            url = program.a['href'].split('/')
            if (town in HseEduProgramsWebScraper.TARGET_TOWNS) and ('ba' in url) and \
               (url[2] in HseEduProgramsWebScraper.REGULAR_DOMAINS):
                name = sanitize_str(program.a.text)
                code = url[-2]
                self.programs[name] = code
                if faculty not in self.faculties:   
                    self.faculties[faculty] = set()
                self.faculties[faculty].add(name)
        
        # Из-за особенностей полученных данных, необходимо отождествить все пары факультетов,
        # название одного из которых является префиксом другого
        duplicates = []
        for faculty_i in self.faculties:
            for faculty_j in self.faculties:
                if faculty_i != faculty_j and faculty_i.find(faculty_j) != -1:
                    for program in self.faculties[faculty_i]:
                        self.faculties[faculty_j].add(program)
                    duplicates.append(faculty_i)
        for dup in duplicates:
            self.faculties.pop(dup)
        
        self.loaded = True
        return self.faculties, self.programs

# %% [markdown]
# **Класс, реализующий скрапинг страниц с рейтингами:**

# %%
class HseRatingGetter:
    def __init__(self, program: str, scraper: HseEduProgramsWebScraper):
        programs = scraper.get()[1]
        if program not in programs:
            raise ValueError('There is no such program in educational program list')
        self.url_code = programs[program]
        
    def __call__(self, rating_name: str, course: int) -> pd.DataFrame:
        parser = BeautifulSoupHtmlParser('html.parser')
        url = f'https://www.hse.ru/ba/{self.url_code}/ratings'
        try:
            soup = parser(url)
        except BadResponseError:
            raise
        url_from = None
        for option in soup('div', 'first_child last_child')[0]('select')[0]('option'):
            if option.text == rating_name:
                url_from = option['value']
                break
        else:
            raise ValueError('Irregular rating page or incorrect rating name')
        for option in soup('div', 'first_child last_child')[0]('select')[1]('option'):
            if course == int(option['value']):
                break
        else:
            raise ValueError('Incorrect course value')
        
        url = f'https://www.hse.ru/ba/{self.url_code}/ratings?from={url_from}&course={course}'
        try:
            soup = parser(url)
        except BadResponseError:
            raise
        names = []
        positions = []
        grade_mids = []
        grade_mins = []
        percentiles = []
        gpas = []
        for tr in soup('table')[0]('tr')[1:]:
            names.append(tr('td')[0].text)
            positions.append(tr('td')[1].text)
            if tr('td')[2].text != '':
                grade_mids.append(float(tr('td')[2].text))
            else:
                grade_mids.append(float('nan'))
            if tr('td')[3].text != '':
                grade_mins.append(int(tr('td')[3].text))
            else:
                grade_mins.append(float('nan'))
            percentiles.append(float(tr('td')[4].text[:-1]))
            gpas.append(float(tr('td')[5].text))
        
        res = pd.DataFrame(
            {
                'Студент': names,
                'Позиция в рейтинге': positions,
                'Средний балл': grade_mids,
                'Минимальный балл': grade_mins,
                'Перцентиль': percentiles,
                'GPA': gpas
            }
        )
        return res

# %% [markdown]
# Проверим, что всё работает:

# %%
scraper = HseEduProgramsWebScraper() # всегда используется далее для передачи в конструктор объекта типа HseRatingGetter

rating_getter = HseRatingGetter('Культурология', scraper)
rating = rating_getter('Кумулятивный рейтинг по итогам 1-2 модулей 2020/2021 уч.г.', 3)
rating.head()
# Out:
#                          Студент Позиция в рейтинге  Средний балл  \
# 0   Борисова Дарья Александровна                  1          7.03
# 1    Чефанова Елизавета Игоревна                  2          9.42
# 2    Кожаринова Мария Викторовна                  3          9.51
# 3       Кузнецова Яна Михайловна                  4          8.98
# 4  Болгарина Дарья Александровна                  5          8.93
#
#    Минимальный балл  Перцентиль   GPA
# 0                 4        0.00  6.85
# 1                 7        1.96  9.48
# 2                 8        3.92  9.51
# 3                 6        5.88  9.11
# 4                 6        7.84  9.06

# %% [markdown]
# Видим, что у человека на первом месте слишком низкие показатели по сравнению с теми, кто ниже. На самом деле, это распространённое явление. Кажется, что это результат технических ошибок при формировании рейтинга. Но на наш дальнейший анализ это не повлияет, поэтому оставим как есть.
#
# Однако бывают случаи совсем странные, когда у человека средний балл меньше минимального. Очевидно, такого не может быть, поэтому, для чистоты анализа, будем фильтровать таких студнетов. Также отфильтруем тех, у кого по какой-то причине хотя бы одно поле было не заполнено. Напишем соответствующую функцию:

# %%
def sanitized_rating(rating: pd.DataFrame) -> pd.DataFrame:
    rating.dropna(inplace=True)
    return rating[rating['Средний балл'] >= rating['Минимальный балл']]

# %% [markdown]
# Проверим:

# %%
rating_getter = HseRatingGetter('Прикладная математика и информатика', scraper)
rating = rating_getter('Текущий рейтинг после пересдач 2018/2019 уч.г. (3-4 модули)', 2)
print(len(rating), len(sanitized_rating(rating)))
# Out:
# 225 223

# %% [markdown]
# Теперь, для удобства, забьём названия всех доступных на данный момент рейтингов в словарь:

# %%
RATING_NAME = {
    2018: {
        1: {
            'cr':  'Текущий рейтинг 2018/2019уч.г. (1 семестр)',
            'crr': 'Текущий рейтинг после пересдач 2018/2019уч.г. (1-2 модули)',
            'cm':  'Кумулятивный рейтинг по итогам 1-2 модулей 2018/2019 уч.г.'
        },
        2: {
            'cr':  'Текущий рейтинг 2018/2019 учебного года (3-4 модули)',
            'crr': 'Текущий рейтинг после пересдач 2018/2019 уч.г. (3-4 модули)',
            'cm':  'Кумулятивный рейтинг по итогам 3-4 модулей 2018/2019 уч.г.',
            'gr':  'Рейтинг выпускников 2018/2019 уч.г.'
        }
    },
    2019: {
        1: {
            'cr':  'Текущий рейтинг 2019/2020 учебного года (1-2 модули)',
            'crr': 'Текущий рейтинг после пересдач 2019/2020 учебного года (1-2 модули)',
            'cm':  'Кумулятивный рейтинг по итогам 1-2 модулей 2019/2020 уч.г.'
        },
        2: {
            'cr':  'Текущий рейтинг 2019/2020 учебного года (3-4 модули)',
            'crr': 'Текущий рейтинг после пересдач 2019/2020 учебного года (3-4 модули)',
            'cm':  'Кумулятивный рейтинг по итогам 3-4 модулей 2019/2020 уч.г.',
            'gr':  'Рейтинг выпускников 2019/2020 уч.г.'
        }
    },
    2020: {
        1: {
            'cr':  'Текущий рейтинг 2020/2021 учебного года (1-2 модули)',
            'crr': 'Текущий рейтинг после пересдач 2020/2021 учебного года (1-2 модули)',
            'cm':  'Кумулятивный рейтинг по итогам 1-2 модулей 2020/2021 уч.г.'
        },
        2: {
            'cr':  'Текущий рейтинг 2020/2021 учебного года (3-4 модули)',
            'gr':  'Рейтинг выпускников 2020/2021 уч.г.'
        }
    }
}

# %% [markdown]
# Приступим к написанию функций, с помощью которых мы соберём и проанализируем интересующие нас данные.
# **Функция для вычисления среднего GPA** (использует текущий рейтинг до пересдач запрошенного периода):

# %%
def mean_gpa(program: str, year: int, term: int, course: int, scraper: HseEduProgramsWebScraper) -> float:
    rating_getter = HseRatingGetter(program, scraper)
    rating = rating_getter(RATING_NAME[year][term]['cr'], course)
    rating = sanitized_rating(rating)
    if rating.empty:
        return -1
    return rating['GPA'].mean()

# %%
mean_gpa('Программная инженерия', 2020, 1, 2, scraper)
# Out:
# 6.795770750988143

# %% [markdown]
# Теперь напишем **функцию для подсчёта числа отчисленных студентов за данный учебный год**. Считаем, что студент отчислен, если в некотором текущем рейтинге до пересдач запись о нем имеется, а в текущем рейтинге того же периода после пересдач &mdash; не имеется.

# %%
from typing import List


def calculate_rating_difference(names_cr: List[str], names_crr: List[str]) -> int:
    expelled = 0
    for student in names_cr:
        if student not in names_crr:
            expelled += 1
    return expelled


def count_expelled(program: str, year: int, course: int, scraper: HseEduProgramsWebScraper) -> int:
    rating_getter = HseRatingGetter(program, scraper)
    rating_cr_1 = rating_getter(RATING_NAME[year][1]['cr'], course)
    rating_crr_1 = rating_getter(RATING_NAME[year][1]['crr'], course)
    if rating_cr_1.empty or rating_crr_1.empty:
        return -1
    res_1 = calculate_rating_difference(list(rating_cr_1['Студент']), list(rating_crr_1['Студент']))
    
    res_2 = 0
    if year != 2020 or course == 4: # пересдачи за 2020/2021 учебный год на данный момент еще не состоялись
        rating_cr_2 = rating_getter(RATING_NAME[year][2]['cr'], course)
        rating_crr_2 = rating_getter(RATING_NAME[year][2]['crr'], course + 1) if course < 4 else \
                       rating_getter(RATING_NAME[year][2]['gr'], course)
        res_2 = calculate_rating_difference(list(rating_cr_2['Студент']), list(rating_crr_2['Студент']))

    return res_1 + res_2

# %%
count_expelled('Мировая экономика', 2020, 2, scraper)
# Out:
# 6

# %% [markdown]
# ## 3. Сбор, анализ и визуализация данных
#
# Для начала сгенерируем сокращения для названий факультетов, чтобы они помещались на графиках:

# %%
faculties = scraper.get()[0]
alias = {}
for faculty in faculties:
    alias[faculty] = ''.join([token[0].upper() for token in faculty.split() if token != 'и'])

# поправим некоторые сокращения
alias['Факультет мировой экономики и мировой политики'] = 'ФМЭиМП'
alias['Московский институт электроники и математики им. А.Н. Тихонова'] = 'МИЭМ'
alias
# Out:
# {'Факультет городского и регионального развития': 'ФГРР',
#  'Факультет биологии и биотехнологии': 'ФББ',
#  'Институт классического Востока и античности': 'ИКВА',
#  'Факультет мировой экономики и мировой политики': 'ФМЭиМП',
#  'Московский институт электроники и математики им. А.Н. Тихонова': 'МИЭМ',
#  'Факультет компьютерных наук': 'ФКН',
#  'Факультет гуманитарных наук': 'ФГН',
#  'Факультет математики': 'ФМ',
#  'Факультет географии и геоинформационных технологий': 'ФГГТ',
#  'Факультет социальных наук': 'ФСН',
#  'Факультет коммуникаций, медиа и дизайна': 'ФКМД',
#  'Факультет физики': 'ФФ',
#  'Факультет химии': 'ФХ',
#  'Высшая школа бизнеса': 'ВШБ',
#  'Международный институт экономики и финансов': 'МИЭФ',
#  'Факультет экономических наук': 'ФЭН',
#  'Факультет права': 'ФП',
#  'Школа иностранных языков': 'ШИЯ'}

# %% [markdown]
# Теперь приступим к сбору и анализу интересующих нас данных. Для всех факультетов за каждый учебный год (для которого доступен рейтинг на соответствующей странице) для каждого курса будем усреднять среднее GPA и количество отчисленных студентов по всем ОП, реализуемым на данном факультете:

# %%
means = {
    2018: {}, 2019: {}, 2020: {}
}
expelled = {
    2018: {}, 2019: {}, 2020: {}
}

for year in [2018, 2019, 2020]:
    print(year)
    for course in [1, 2, 3, 4]:
        print('-', course)
        means[year][course] = {}
        expelled[year][course] = {}
        for faculty in faculties:
            print('--', alias[faculty])
            mean_sum = 0
            mean_cnt = 0
            exp_sum = 0
            exp_cnt = 0
            for program in faculties[faculty]:
                print('---', program)
                try:
                    m = [mean_gpa(program, year, term, course, scraper) for term in [1, 2]]
                    cnt = count_expelled(program, year, course, scraper)
                except Exception as e:
                    print(str(e))
                    continue
                if m[0] != -1 and m[1] != -1:
                    mean_sum += (m[0] + m[1]) / 2
                    mean_cnt += 1
                if cnt != -1:
                    exp_sum += cnt
                    exp_cnt += 1
            means[year][course][alias[faculty]] = mean_sum / mean_cnt if mean_cnt != 0 else -1        
            expelled[year][course][alias[faculty]] = exp_sum / exp_cnt if exp_cnt != 0 else -1
            print('--', f'mean = {means[year][course][alias[faculty]]}, exp = {expelled[year][course][alias[faculty]]}')
# Out:
# 2018
# - 1
# -- ФГРР
# --- Городское планирование
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.807768848709339, exp = 17.4
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.0215525571486666, exp = 14.5
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.686211090422161, exp = 19.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.396084448696588, exp = 12.166666666666666
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.830121950041889, exp = 8.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.138248548176577, exp = 13.0
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.851467369232128, exp = 22.0
# -- ФФ
# --- Физика
# -- mean = 7.725092332396628, exp = 2.0
# -- ФХ
# --- Химия
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.021096834051905, exp = 21.8
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 6.220911739441662, exp = 51.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.6526376750520795, exp = 18.333333333333332
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.108974772339216, exp = 14.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.954772094201067, exp = 45.0
# - 2
# -- ФГРР
# --- Городское планирование
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 7.114283476554392, exp = 9.0
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.04755212503828, exp = 7.25
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.945283206013362, exp = 19.5
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.2266124984274756, exp = 4.666666666666667
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.1631959502843525, exp = 4.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.173501143654037, exp = 6.75
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.556120309187489, exp = 17.333333333333332
# -- ФФ
# --- Физика
# -- mean = 7.03125, exp = 1.0
# -- ФХ
# --- Химия
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.464728204476156, exp = 6.5
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 2.683631524725275, exp = 53.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.83941959098367, exp = 16.333333333333332
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.407916870709759, exp = 4.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.886273178640186, exp = 15.0
# - 3
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.773531526216315, exp = 3.75
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.417949485471878, exp = 2.25
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.9393092962390055, exp = 16.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.3556556344447825, exp = 2.3333333333333335
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 8.014229587357331, exp = 3.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.470293437151515, exp = 1.75
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.88380514020166, exp = 5.333333333333333
# -- ФФ
# --- Физика
# -- mean = -1, exp = -1
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.388618296832053, exp = 2.5
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 2.4525833333333336, exp = 45.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.768434145343999, exp = 4.666666666666667
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.782232107157135, exp = 6.0
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.639242878082977, exp = 19.0
# - 4
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# Incorrect course value
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.487987805987807, exp = 6.0
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.331419585696113, exp = 10.25
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# Incorrect course value
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.1525846722971815, exp = 13.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 6.1891836322858165, exp = 3.5
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = -1, exp = 2.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 6.679895890623701, exp = 6.75
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.178718635421649, exp = 3.0
# -- ФФ
# --- Физика
# -- mean = -1, exp = -1
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# Incorrect course value
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.508903963980504, exp = 26.0
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 5.058624351109014, exp = 21.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 5.536126709836388, exp = 10.666666666666666
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 6.924604978354976, exp = 11.0
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.897346258503403, exp = 51.0
# 2019
# - 1
# -- ФГРР
# --- Городское планирование
# -- mean = 7.9362328265250035, exp = 7.0
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = 7.703636363636364, exp = 3.0
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = 7.951388888888888, exp = 3.0
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.847559630383361, exp = 18.6
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.016224270826828, exp = 12.6
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.290434686103574, exp = 31.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.457133006217778, exp = 16.166666666666668
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.618623228250245, exp = 9.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 6.992691194087134, exp = 16.0
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 8.014575815890682, exp = 17.0
# -- ФФ
# --- Физика
# -- mean = 7.6377333333333315, exp = 13.0
# -- ФХ
# --- Химия
# -- mean = 7.22143918918919, exp = 4.0
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.903803406980783, exp = 23.4
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 3.8292993543069103, exp = 66.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.957183915316134, exp = 16.0
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.185842664121322, exp = 11.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 8.292509437212043, exp = 21.0
# - 2
# -- ФГРР
# --- Городское планирование
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.811149528059104, exp = 6.4
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.13969871462322, exp = 10.5
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.361639272362793, exp = 8.333333333333334
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.680580195267214, exp = 4.833333333333333
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.818820488721807, exp = 2.5
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.293011310321243, exp = 6.5
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.925125448145536, exp = 16.333333333333332
# -- ФФ
# --- Физика
# -- mean = 7.371354166666668, exp = 3.0
# -- ФХ
# --- Химия
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.25643822059447, exp = 11.6
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 1.1073333333333335, exp = 17.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.638983977842218, exp = 14.0
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.67782742055535, exp = 5.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.742600698312255, exp = 21.0
# - 3
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.969775984351954, exp = 3.75
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.541613254568334, exp = 3.0
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 7.099159218080082, exp = 6.5
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.1320175898847396, exp = 3.6666666666666665
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.125007411067195, exp = 4.5
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.709634537991998, exp = 2.75
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.941772952802431, exp = 4.333333333333333
# -- ФФ
# --- Физика
# -- mean = 7.704000000000001, exp = 0.0
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.358041016769301, exp = 5.25
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 1.3412878787878788, exp = 2.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.883973205163225, exp = 6.0
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.775410784800551, exp = 2.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.892964221248064, exp = 6.0
# - 4
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# Incorrect course value
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 7.264296311372131, exp = 41.0
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.9130726504819116, exp = 43.5
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# Incorrect course value
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.874893161990364, exp = 63.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.540553532611834, exp = 21.666666666666668
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 8.05781686804075, exp = 31.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 8.094451091638103, exp = 42.75
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 8.094248848516754, exp = 88.66666666666667
# -- ФФ
# --- Физика
# -- mean = -1, exp = -1
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# Incorrect course value
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.595200092312774, exp = 106.0
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 4.717875445632798, exp = 62.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 7.189310595925053, exp = 56.333333333333336
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.80032910110609, exp = 144.0
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 8.15001773970232, exp = 45.0
# 2020
# - 1
# -- ФГРР
# --- Городское планирование
# -- mean = 8.018557840009453, exp = 1.0
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = 7.6625555555555565, exp = 2.0
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = 6.653118440779609, exp = 6.0
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.827377072193107, exp = 5.6
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.306312805432472, exp = 7.0
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.514517905292986, exp = 11.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.4218626326706625, exp = 3.1666666666666665
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.639880107811573, exp = 3.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = 0.0
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.411227015241489, exp = 5.5
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.924513744100369, exp = 3.3333333333333335
# -- ФФ
# --- Физика
# -- mean = 7.229457417582418, exp = 0.0
# -- ФХ
# --- Химия
# -- mean = 8.000087108013938, exp = 0.0
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.609924218953687, exp = 3.8
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 3.3125545171339548, exp = 2.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.334869457584929, exp = 11.0
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.246212407145385, exp = 2.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 8.243726344488401, exp = 5.0
# - 2
# -- ФГРР
# --- Городское планирование
# -- mean = 7.004188681271479, exp = 1.0
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# -- mean = 7.943679245283018, exp = 0.0
# -- ИКВА
# --- Античность
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = 7.983361344537815, exp = 2.0
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 6.80606458543745, exp = 3.4
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.079264900901039, exp = 3.4
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.0528728664172675, exp = 2.3333333333333335
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.484634467403471, exp = 1.6666666666666667
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.4262084745762715, exp = 1.5
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.226417659937162, exp = 1.0
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.993266968347346, exp = 8.333333333333334
# -- ФФ
# --- Физика
# -- mean = 7.980903157255616, exp = 0.0
# -- ФХ
# --- Химия
# -- mean = 6.96486274509804, exp = 1.0
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.937680867051076, exp = 1.2
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 3.465090909090911, exp = 1.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 7.018950561526663, exp = 3.3333333333333335
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.494322200041975, exp = 1.0
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.889422466422463, exp = 4.0
# - 3
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 7.192731426579298, exp = 3.0
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 7.445145812714697, exp = 0.75
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 6.6720115144547405, exp = 0.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.4547080015344145, exp = 1.3333333333333333
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.408012828220972, exp = 2.0
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 7.43432653979552, exp = 1.25
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 7.792560008831377, exp = 3.0
# -- ФФ
# --- Физика
# -- mean = 7.3237619617224885, exp = 0.0
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 6.844180594397933, exp = 0.8
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 2.629106280193237, exp = 2.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 6.889071722179772, exp = 3.6666666666666665
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.877345520484413, exp = 0.0
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 7.926643105320306, exp = 7.0
# - 4
# -- ФГРР
# --- Городское планирование
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФББ
# --- Клеточная и молекулярная биотехнология
# Incorrect course value
# -- mean = -1, exp = -1
# -- ИКВА
# --- Античность
# Incorrect course value
# --- Язык, словесность и культура Китая
# Bad response status code: 404
# --- Христианский Восток
# Bad response status code: 404
# --- Арабистика: язык, словесность, культура
# Bad response status code: 404
# -- mean = -1, exp = -1
# -- ФМЭиМП
# --- Востоковедение
# --- Мировая экономика
# --- Международные отношения
# --- Программа двух дипломов НИУ ВШЭ и Университета Кёнхи «Экономика и политика в Азии»
# Incorrect course value
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета по международным отношениям
# -- mean = 7.941773863644988, exp = 1.0
# -- МИЭМ
# --- Компьютерная безопасность
# --- Прикладная математика
# --- Информационная безопасность
# Incorrect course value
# --- Информатика и вычислительная техника
# --- Инфокоммуникационные технологии и системы связи
# -- mean = 8.021929341922126, exp = 1.5
# -- ФКН
# --- Программная инженерия
# --- Программа двух дипломов НИУ ВШЭ и Лондонского университета «Прикладной анализ данных»
# Incorrect course value
# --- Компьютерные науки и анализ данных
# Bad response status code: 404
# --- Прикладная математика и информатика
# -- mean = 7.257709839310188, exp = 1.0
# -- ФГН
# --- История искусств
# --- Филология
# --- Философия
# --- История
# --- Фундаментальная и компьютерная лингвистика
# --- Культурология
# -- mean = 7.411031499642841, exp = 1.1666666666666667
# -- ФМ
# --- Совместный бакалавриат НИУ ВШЭ и ЦПМ
# --- Математика
# -- mean = 7.451467728758169, exp = 0.5
# -- ФГГТ
# --- География глобальных изменений и геоинформационные технологии
# Incorrect course value
# -- mean = -1, exp = -1
# -- ФСН
# --- Политология
# --- Психология
# --- Государственное и муниципальное управление
# --- Социология
# -- mean = 8.041101670137198, exp = 1.25
# -- ФКМД
# --- Реклама и связи с общественностью
# --- Журналистика
# --- Медиакоммуникации
# -- mean = 8.250080224867723, exp = 1.0
# -- ФФ
# --- Физика
# -- mean = 8.319642857142856, exp = 0.0
# -- ФХ
# --- Химия
# Incorrect course value
# -- mean = -1, exp = -1
# -- ВШБ
# --- Цифровые инновации в управлении предприятием (программа двух дипломов НИУ ВШЭ и Лондонского университета)
# Incorrect course value
# --- Маркетинг и рыночная аналитика
# --- Управление бизнесом
# --- Логистика и управление цепями поставок
# --- Бизнес-информатика
# -- mean = 7.778341621955656, exp = 0.75
# -- МИЭФ
# --- Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета
# -- mean = 5.814643280632412, exp = 0.0
# -- ФЭН
# --- Совместная программа по экономике НИУ ВШЭ и РЭШ
# --- Экономика и статистика
# --- Экономика
# -- mean = 7.641792851248066, exp = 2.0
# -- ФП
# --- Юриспруденция
# --- Юриспруденция: частное право
# -- mean = 7.9664199203574215, exp = 1.5
# -- ШИЯ
# --- Иностранные языки и межкультурная коммуникация
# -- mean = 8.239425520410924, exp = 1.0

# %%
means, expelled
# Out:
# ({2018: {1: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.807768848709339,
#     'МИЭМ': 7.0215525571486666,
#     'ФКН': 6.686211090422161,
#     'ФГН': 7.396084448696588,
#     'ФМ': 7.830121950041889,
#     'ФГГТ': -1,
#     'ФСН': 7.138248548176577,
#     'ФКМД': 7.851467369232128,
#     'ФФ': 7.725092332396628,
#     'ФХ': -1,
#     'ВШБ': 7.021096834051905,
#     'МИЭФ': 6.220911739441662,
#     'ФЭН': 6.6526376750520795,
#     'ФП': 7.108974772339216,
#     'ШИЯ': 7.954772094201067},
#    2: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 7.114283476554392,
#     'МИЭМ': 7.04755212503828,
#     'ФКН': 6.945283206013362,
#     'ФГН': 7.2266124984274756,
#     'ФМ': 7.1631959502843525,
#     'ФГГТ': -1,
#     'ФСН': 7.173501143654037,
#     'ФКМД': 7.556120309187489,
#     'ФФ': 7.03125,
#     'ФХ': -1,
#     'ВШБ': 7.464728204476156,
#     'МИЭФ': 2.683631524725275,
#     'ФЭН': 6.83941959098367,
#     'ФП': 7.407916870709759,
#     'ШИЯ': 7.886273178640186},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.773531526216315,
#     'МИЭМ': 7.417949485471878,
#     'ФКН': 6.9393092962390055,
#     'ФГН': 7.3556556344447825,
#     'ФМ': 8.014229587357331,
#     'ФГГТ': -1,
#     'ФСН': 7.470293437151515,
#     'ФКМД': 7.88380514020166,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 7.388618296832053,
#     'МИЭФ': 2.4525833333333336,
#     'ФЭН': 6.768434145343999,
#     'ФП': 7.782232107157135,
#     'ШИЯ': 7.639242878082977},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.487987805987807,
#     'МИЭМ': 7.331419585696113,
#     'ФКН': 6.1525846722971815,
#     'ФГН': 6.1891836322858165,
#     'ФМ': -1,
#     'ФГГТ': -1,
#     'ФСН': 6.679895890623701,
#     'ФКМД': 7.178718635421649,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 6.508903963980504,
#     'МИЭФ': 5.058624351109014,
#     'ФЭН': 5.536126709836388,
#     'ФП': 6.924604978354976,
#     'ШИЯ': 7.897346258503403}},
#   2019: {1: {'ФГРР': 7.9362328265250035,
#     'ФББ': 7.703636363636364,
#     'ИКВА': 7.951388888888888,
#     'ФМЭиМП': 6.847559630383361,
#     'МИЭМ': 7.016224270826828,
#     'ФКН': 6.290434686103574,
#     'ФГН': 7.457133006217778,
#     'ФМ': 7.618623228250245,
#     'ФГГТ': -1,
#     'ФСН': 6.992691194087134,
#     'ФКМД': 8.014575815890682,
#     'ФФ': 7.6377333333333315,
#     'ФХ': 7.22143918918919,
#     'ВШБ': 6.903803406980783,
#     'МИЭФ': 3.8292993543069103,
#     'ФЭН': 6.957183915316134,
#     'ФП': 7.185842664121322,
#     'ШИЯ': 8.292509437212043},
#    2: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.811149528059104,
#     'МИЭМ': 7.13969871462322,
#     'ФКН': 6.361639272362793,
#     'ФГН': 7.680580195267214,
#     'ФМ': 7.818820488721807,
#     'ФГГТ': -1,
#     'ФСН': 7.293011310321243,
#     'ФКМД': 7.925125448145536,
#     'ФФ': 7.371354166666668,
#     'ФХ': -1,
#     'ВШБ': 6.25643822059447,
#     'МИЭФ': 1.1073333333333335,
#     'ФЭН': 6.638983977842218,
#     'ФП': 7.67782742055535,
#     'ШИЯ': 7.742600698312255},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.969775984351954,
#     'МИЭМ': 7.541613254568334,
#     'ФКН': 7.099159218080082,
#     'ФГН': 7.1320175898847396,
#     'ФМ': 7.125007411067195,
#     'ФГГТ': -1,
#     'ФСН': 7.709634537991998,
#     'ФКМД': 7.941772952802431,
#     'ФФ': 7.704000000000001,
#     'ФХ': -1,
#     'ВШБ': 7.358041016769301,
#     'МИЭФ': 1.3412878787878788,
#     'ФЭН': 6.883973205163225,
#     'ФП': 7.775410784800551,
#     'ШИЯ': 7.892964221248064},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 7.264296311372131,
#     'МИЭМ': 7.9130726504819116,
#     'ФКН': 6.874893161990364,
#     'ФГН': 7.540553532611834,
#     'ФМ': 8.05781686804075,
#     'ФГГТ': -1,
#     'ФСН': 8.094451091638103,
#     'ФКМД': 8.094248848516754,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 7.595200092312774,
#     'МИЭФ': 4.717875445632798,
#     'ФЭН': 7.189310595925053,
#     'ФП': 7.80032910110609,
#     'ШИЯ': 8.15001773970232}},
#   2020: {1: {'ФГРР': 8.018557840009453,
#     'ФББ': 7.6625555555555565,
#     'ИКВА': 6.653118440779609,
#     'ФМЭиМП': 6.827377072193107,
#     'МИЭМ': 7.306312805432472,
#     'ФКН': 6.514517905292986,
#     'ФГН': 7.4218626326706625,
#     'ФМ': 7.639880107811573,
#     'ФГГТ': -1,
#     'ФСН': 7.411227015241489,
#     'ФКМД': 7.924513744100369,
#     'ФФ': 7.229457417582418,
#     'ФХ': 8.000087108013938,
#     'ВШБ': 6.609924218953687,
#     'МИЭФ': 3.3125545171339548,
#     'ФЭН': 6.334869457584929,
#     'ФП': 7.246212407145385,
#     'ШИЯ': 8.243726344488401},
#    2: {'ФГРР': 7.004188681271479,
#     'ФББ': 7.943679245283018,
#     'ИКВА': 7.983361344537815,
#     'ФМЭиМП': 6.80606458543745,
#     'МИЭМ': 7.079264900901039,
#     'ФКН': 6.0528728664172675,
#     'ФГН': 7.484634467403471,
#     'ФМ': 7.4262084745762715,
#     'ФГГТ': -1,
#     'ФСН': 7.226417659937162,
#     'ФКМД': 7.993266968347346,
#     'ФФ': 7.980903157255616,
#     'ФХ': 6.96486274509804,
#     'ВШБ': 6.937680867051076,
#     'МИЭФ': 3.465090909090911,
#     'ФЭН': 7.018950561526663,
#     'ФП': 7.494322200041975,
#     'ШИЯ': 7.889422466422463},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 7.192731426579298,
#     'МИЭМ': 7.445145812714697,
#     'ФКН': 6.6720115144547405,
#     'ФГН': 7.4547080015344145,
#     'ФМ': 7.408012828220972,
#     'ФГГТ': -1,
#     'ФСН': 7.43432653979552,
#     'ФКМД': 7.792560008831377,
#     'ФФ': 7.3237619617224885,
#     'ФХ': -1,
#     'ВШБ': 6.844180594397933,
#     'МИЭФ': 2.629106280193237,
#     'ФЭН': 6.889071722179772,
#     'ФП': 7.877345520484413,
#     'ШИЯ': 7.926643105320306},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 7.941773863644988,
#     'МИЭМ': 8.021929341922126,
#     'ФКН': 7.257709839310188,
#     'ФГН': 7.411031499642841,
#     'ФМ': 7.451467728758169,
#     'ФГГТ': -1,
#     'ФСН': 8.041101670137198,
#     'ФКМД': 8.250080224867723,
#     'ФФ': 8.319642857142856,
#     'ФХ': -1,
#     'ВШБ': 7.778341621955656,
#     'МИЭФ': 5.814643280632412,
#     'ФЭН': 7.641792851248066,
#     'ФП': 7.9664199203574215,
#     'ШИЯ': 8.239425520410924}}},
#  {2018: {1: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 17.4,
#     'МИЭМ': 14.5,
#     'ФКН': 19.0,
#     'ФГН': 12.166666666666666,
#     'ФМ': 8.0,
#     'ФГГТ': -1,
#     'ФСН': 13.0,
#     'ФКМД': 22.0,
#     'ФФ': 2.0,
#     'ФХ': -1,
#     'ВШБ': 21.8,
#     'МИЭФ': 51.0,
#     'ФЭН': 18.333333333333332,
#     'ФП': 14.5,
#     'ШИЯ': 45.0},
#    2: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 9.0,
#     'МИЭМ': 7.25,
#     'ФКН': 19.5,
#     'ФГН': 4.666666666666667,
#     'ФМ': 4.0,
#     'ФГГТ': -1,
#     'ФСН': 6.75,
#     'ФКМД': 17.333333333333332,
#     'ФФ': 1.0,
#     'ФХ': -1,
#     'ВШБ': 6.5,
#     'МИЭФ': 53.0,
#     'ФЭН': 16.333333333333332,
#     'ФП': 4.5,
#     'ШИЯ': 15.0},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 3.75,
#     'МИЭМ': 2.25,
#     'ФКН': 16.0,
#     'ФГН': 2.3333333333333335,
#     'ФМ': 3.0,
#     'ФГГТ': -1,
#     'ФСН': 1.75,
#     'ФКМД': 5.333333333333333,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 2.5,
#     'МИЭФ': 45.0,
#     'ФЭН': 4.666666666666667,
#     'ФП': 6.0,
#     'ШИЯ': 19.0},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.0,
#     'МИЭМ': 10.25,
#     'ФКН': 13.0,
#     'ФГН': 3.5,
#     'ФМ': 2.0,
#     'ФГГТ': -1,
#     'ФСН': 6.75,
#     'ФКМД': 3.0,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 26.0,
#     'МИЭФ': 21.0,
#     'ФЭН': 10.666666666666666,
#     'ФП': 11.0,
#     'ШИЯ': 51.0}},
#   2019: {1: {'ФГРР': 7.0,
#     'ФББ': 3.0,
#     'ИКВА': 3.0,
#     'ФМЭиМП': 18.6,
#     'МИЭМ': 12.6,
#     'ФКН': 31.0,
#     'ФГН': 16.166666666666668,
#     'ФМ': 9.0,
#     'ФГГТ': -1,
#     'ФСН': 16.0,
#     'ФКМД': 17.0,
#     'ФФ': 13.0,
#     'ФХ': 4.0,
#     'ВШБ': 23.4,
#     'МИЭФ': 66.0,
#     'ФЭН': 16.0,
#     'ФП': 11.5,
#     'ШИЯ': 21.0},
#    2: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 6.4,
#     'МИЭМ': 10.5,
#     'ФКН': 8.333333333333334,
#     'ФГН': 4.833333333333333,
#     'ФМ': 2.5,
#     'ФГГТ': -1,
#     'ФСН': 6.5,
#     'ФКМД': 16.333333333333332,
#     'ФФ': 3.0,
#     'ФХ': -1,
#     'ВШБ': 11.6,
#     'МИЭФ': 17.0,
#     'ФЭН': 14.0,
#     'ФП': 5.5,
#     'ШИЯ': 21.0},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 3.75,
#     'МИЭМ': 3.0,
#     'ФКН': 6.5,
#     'ФГН': 3.6666666666666665,
#     'ФМ': 4.5,
#     'ФГГТ': -1,
#     'ФСН': 2.75,
#     'ФКМД': 4.333333333333333,
#     'ФФ': 0.0,
#     'ФХ': -1,
#     'ВШБ': 5.25,
#     'МИЭФ': 2.0,
#     'ФЭН': 6.0,
#     'ФП': 2.5,
#     'ШИЯ': 6.0},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 41.0,
#     'МИЭМ': 43.5,
#     'ФКН': 63.0,
#     'ФГН': 21.666666666666668,
#     'ФМ': 31.0,
#     'ФГГТ': -1,
#     'ФСН': 42.75,
#     'ФКМД': 88.66666666666667,
#     'ФФ': -1,
#     'ФХ': -1,
#     'ВШБ': 106.0,
#     'МИЭФ': 62.0,
#     'ФЭН': 56.333333333333336,
#     'ФП': 144.0,
#     'ШИЯ': 45.0}},
#   2020: {1: {'ФГРР': 1.0,
#     'ФББ': 2.0,
#     'ИКВА': 6.0,
#     'ФМЭиМП': 5.6,
#     'МИЭМ': 7.0,
#     'ФКН': 11.0,
#     'ФГН': 3.1666666666666665,
#     'ФМ': 3.0,
#     'ФГГТ': 0.0,
#     'ФСН': 5.5,
#     'ФКМД': 3.3333333333333335,
#     'ФФ': 0.0,
#     'ФХ': 0.0,
#     'ВШБ': 3.8,
#     'МИЭФ': 2.0,
#     'ФЭН': 11.0,
#     'ФП': 2.5,
#     'ШИЯ': 5.0},
#    2: {'ФГРР': 1.0,
#     'ФББ': 0.0,
#     'ИКВА': 2.0,
#     'ФМЭиМП': 3.4,
#     'МИЭМ': 3.4,
#     'ФКН': 2.3333333333333335,
#     'ФГН': 1.6666666666666667,
#     'ФМ': 1.5,
#     'ФГГТ': -1,
#     'ФСН': 1.0,
#     'ФКМД': 8.333333333333334,
#     'ФФ': 0.0,
#     'ФХ': 1.0,
#     'ВШБ': 1.2,
#     'МИЭФ': 1.0,
#     'ФЭН': 3.3333333333333335,
#     'ФП': 1.0,
#     'ШИЯ': 4.0},
#    3: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 3.0,
#     'МИЭМ': 0.75,
#     'ФКН': 0.0,
#     'ФГН': 1.3333333333333333,
#     'ФМ': 2.0,
#     'ФГГТ': -1,
#     'ФСН': 1.25,
#     'ФКМД': 3.0,
#     'ФФ': 0.0,
#     'ФХ': -1,
#     'ВШБ': 0.8,
#     'МИЭФ': 2.0,
#     'ФЭН': 3.6666666666666665,
#     'ФП': 0.0,
#     'ШИЯ': 7.0},
#    4: {'ФГРР': -1,
#     'ФББ': -1,
#     'ИКВА': -1,
#     'ФМЭиМП': 52.25,
#     'МИЭМ': 18.25,
#     'ФКН': 14.5,
#     'ФГН': 6.833333333333333,
#     'ФМ': 3.0,
#     'ФГГТ': -1,
#     'ФСН': 8.5,
#     'ФКМД': 16.333333333333332,
#     'ФФ': 1.0,
#     'ФХ': -1,
#     'ВШБ': 13.0,
#     'МИЭФ': 43.0,
#     'ФЭН': 14.0,
#     'ФП': 7.5,
#     'ШИЯ': 14.0}}})

# %% [markdown]
# Визуализируем полученное:

# %%
import matplotlib.pyplot as plt


def plot_data(year: int, data: Dict[int, Dict[int, Dict[str, int]]], title: str, ylim: Tuple[int, int]):
    fig = plt.figure()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    fig.suptitle(title + f' за {year}/{year + 1} учебный год')
    sbp = [fig.add_subplot(1, 4, i) for i in [1, 2, 3, 4]]
    for i in range(0, 4):
        sbp[i].set(title=f'{i + 1} курс')
        sbp[i].scatter(data[year][i + 1].keys(), data[year][i + 1].values())
        sbp[i].tick_params(labelrotation=90)
        if ylim is not None:
            sbp[i].set_ylim(ylim)

# %%
plot_data(2018, means, 'Средний GPA', (-2, 10))

# %%
plot_data(2019, means, 'Средний GPA', (-2, 10))

# %%
plot_data(2020, means, 'Средний GPA', (-2, 10))

# %% [markdown]
# Итак, первое, что бросается в глаза, &mdash; минус единицы. Больше всего их в 2018/2019 учебном году. Дело в том, что на тот момент соответствующих факультетов еще просто не было, либо же они появились недавно и на них пока нет студентов старших курсов. Единственная странность тут, что -1 также стоит на 4 курсе Факультета математики (основанном в 2007 году). Взглянем на соответсвующий рейтинг:

# %%
rating_getter = HseRatingGetter('Математика', scraper)
rating = rating_getter('Текущий рейтинг 2018/2019 учебного года (3-4 модули)', 4)
rating
# Out:
#                            Студент Позиция в рейтинге  Средний балл  \
# 0  Рогачевская Анастасия Вадимовна                  1          1.67
#
#    Минимальный балл  Перцентиль   GPA
# 0                 4         0.0  1.28

# %%
len(sanitized_rating(rating))
# Out:
# 0

# %% [markdown]
# Видим, что весь рейтинг представляет собой всего одну запись, которая еще и фильтруется нашей функцией ```sanitized_rating```. Скорее всего, это результат технической ошибки, или, возможно, кто-то забыл выгрузить нужный рейтинг из ЛМС ¯\\_(ツ)_/¯
#
# В следующих учебных годах, как видно, минус единиц становится всё меньше.
#
# Можно сказать, что в среднем (если не считать МИЭФ) студенты учатся примерно на 7. Самые высокие оценки в среднем на ФКМД и ШИЯ. А на родном ФКНе оценки в среднем ниже, чем на большинстве факультетов.
#
# Что касается выбросов по МИЭФу, то при первом взгляде на один из самых свежих рейтингов, сразу складывается ощущение, что это определенно какие-то технические ошибки:

# %%
rating_getter = HseRatingGetter('Программа двух дипломов по экономике НИУ ВШЭ и Лондонского университета', scraper)
rating = rating_getter('Текущий рейтинг 2020/2021 учебного года (3-4 модули)', 3)
rating
# Out:
#                              Студент Позиция в рейтинге  Средний балл  \
# 0         Ёлшина Елена Александровна                  1          2.22
# 1             Адзхед Мария Томасовна                  2          2.11
# 2            Глазков Антон Андреевич                  3          2.00
# 3         Морозов Григорий Андреевич                  4          2.22
# 4                  Шерифф Нил Сахейм                  5          2.11
# ..                               ...                ...           ...
# 233     Шатских Анастасия Максимовна          111 - 238          0.00
# 234        Шерстюк Сергей Дмитриевич          111 - 238          0.00
# 235  Шиваров Александр Александрович          111 - 238          0.00
# 236           Шуклин Фёдор Андреевич          111 - 238          0.00
# 237          Ягафарова Лена Азатовна          111 - 238          0.00
#
#      Минимальный балл  Перцентиль   GPA
# 0                10.0        0.00  1.90
# 1                 9.0        0.42  1.81
# 2                 9.0        0.84  1.71
# 3                 9.0        1.26  1.71
# 4                 9.0        1.68  1.61
# ..                ...         ...   ...
# 233               NaN      100.00  0.00
# 234               NaN      100.00  0.00
# 235               NaN      100.00  0.00
# 236               9.0      100.00  0.00
# 237              10.0      100.00  0.00
#
# [238 rows x 6 columns]

# %%
sanitized_rating(rating)
# Out:
#                       Студент Позиция в рейтинге  Средний балл  \
# 48  Селищев Георгий Артурович                 49           1.2
#
#     Минимальный балл  Перцентиль   GPA
# 48               1.0       20.17  0.83

# %% [markdown]
# С другими текущими рейтингами до пересдач всё примерно так же. Поэтому, кажется, что полученные по МИЭФу данные считать достоверными нельзя.

# %% [markdown]
# Теперь визуализируем данные по отчисленным студентам:

# %%
plot_data(2018, expelled, 'Среднее количество отчисленных', (-5, 55))

# %%
plot_data(2019, expelled, 'Среднее количество отчисленных', (-10, 150))

# %%
plot_data(2020, expelled, 'Среднее количество отчисленных', (-5, 55))

# %% [markdown]
# В общем и целом (если не считать отдельные выбросы по тому же МИЭФу и 4 курс), картина получилась довольно реалистичная.
#
# С МИЭФом, думаю, все ясно, причина та же, скорее всего.
#
# Можно сказать, что в среднем меньше всего отчисляются на 3 курсе. Но примечательно, что довольно много студентов отчисляются на 4 курсе. Это может быть связано с теми же техническими ошибками. Или же моё, в общем-то, довольно логичное предположение о том, что рейтинг выпускников продолжает текущий рейтинг II семестра на 4 курсе неверное. В таком случае, у нас неполная картина и данные, стало быть, достоверными считать нельзя. Наконец, это вполне себе может быть реальностью, и тогда многие студенты, наверное, просто не выдерживают работу над дипломом ¯\\_(ツ)_/¯
